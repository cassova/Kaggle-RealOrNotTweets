# %% [markdown]
# # Real or Not?  NLP with Disaster Tweets
#
# This is my first attempt at creating an NLP ML program.
#
# Some resources I used:
#  - https://www.kaggle.com/philculliton/nlp-getting-started-tutorial
#  - https://www.kaggle.com/abhishek/approaching-almost-any-nlp-problem-on-kaggle
#  - https://www.kaggle.com/gunesevitan/nlp-with-disaster-tweets-eda-cleaning-and-bert

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

pd.set_option('display.max_columns', 500)

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
train_df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# # 1. Data Cleanup

# %%
print (f'Train has {len(train_df)} records\nTest has {len(test_df)} records\n')

null_train_keyword = train_df['keyword'].isnull().sum() / len(train_df) * 100
null_test_keyword = test_df['keyword'].isnull().sum() / len(test_df) * 100
null_train_location = train_df['location'].isnull().sum() / len(train_df) * 100
null_test_location = test_df['location'].isnull().sum() / len(test_df) * 100

print (f'Keyword Values: Train = {round(null_train_keyword,3)}% Test = {round(null_test_keyword,3)}%')
print (f'Location Values: Train = {round(null_train_location,3)}% Test = {round(null_test_location,3)}%')
# Out:
# Train has 7613 records
# Test has 3263 records
#
# Keyword Values: Train = 0.801% Test = 0.797%
# Location Values: Train = 33.272% Test = 33.865%

# %%
# Let's see if we can use a '#' value for our keyword...
null_train_keyword_df = train_df[train_df['keyword'].isnull()]['text'].str.contains('#')

print(f'Train contains {len(null_train_keyword_df)} records with no keywords')
print(f'  {null_train_keyword_df.sum()} of which don\'t have any \'#\'')
# Out:
# Train contains 61 records with no keywords
#   21 of which don't have any '#'

# %% [markdown]
# I'm not going to spend much time on the keyword right now.  I might circle back on this.
#
#
# ### Convert http links, @names, punctuation, etc...
# Examples of the cleanup tasks (This is based on GloVe word vector):
#  - http://my-link --> `<urL>`
#  - @name --> `<user>`
#  - 13,000 --> `<number>`
#  - #topic --> `<hashtag> topic`
#
# Sources:
#  - https://nlp.stanford.edu/projects/glove/preprocess-twitter.rb
#  - https://www.kaggle.com/amackcrane/python-version-of-glove-twitter-preprocess-script

# %%
# Testing area:
eyes = r"[8:=;]"
nose = r"['`\-]?"
df = pd.DataFrame({'test': ['This is ALL CAPS too longggg']})
df['test'].str.replace(r" ([A-Z -_]{2,}) ", r' \1 <allcaps> ')
# Out:
# 0    This is ALL CAPS <allcaps> too longggg
# Name: test, dtype: object

# %%
eyes = r"[8:=;]"
nose = r"['`\-]?"
key_words = ['user', 'number', 'hashtag', 'repeat', 'smile', 
             'lolface', 'sadface', 'neutralface', 'heart',
             'elong', 'allcaps', 'url']

all_data = [train_df, test_df]

for df in all_data:
    # Replace websites URLs
    df['text'] = df['text'].str.replace('http\S+|www.\S+', '<url>', case=False)
    # Replace usernames
    df['text'] = df['text'].str.replace('@\S+', ' <user>')
    # Remove encodings like &amp; and &gt;
    df['text'] = df['text'].str.replace('&\S+;', '') # not used in GloVe
    # Replace numbers
    df['text'] = df['text'].str.replace(r"[-+]?[.\d]*[\d]+[:,.\d]*", "<number>")
    # Replace hashtags
    df['text'] = df['text'].str.replace('#', '<hashtag> ')
    # Replace repeat !! ?? (not words)
    #df['text'] = df['text'].str.replace(r'(?<!\S)((\S+))(?:\s+\2)+(?!\S)', r'\1 <repeat>') # words: my misunderstanding
    df['text'] = df['text'].str.replace(r"([!?.]){2,}", r"\1 <repeat>")
    # Replace emoticons
    df['text'] = df['text'].str.replace(r"{}{}[)dD]+|[)dD]+{}{}".format(eyes, nose, nose, eyes), "<smile>")
    df['text'] = df['text'].str.replace(r"{}{}p+".format(eyes, nose), "<lolface>")
    df['text'] = df['text'].str.replace(r"{}{}\(+|\)+{}{}".format(eyes, nose, nose, eyes), "<sadface>")
    df['text'] = df['text'].str.replace(r"{}{}[\/|l*]".format(eyes, nose), "<neutralface>")
    df['text'] = df['text'].str.replace(r"<3","<heart>")
    # Elongated words like wayyyyy too longgg
    df['text'] = df['text'].str.replace(r"\b(\S*?)(.)\2{2,}\b", r"\1\2 <elong>")
    # ALL CAPS
    df['text'] = df['text'].str.replace(r" ([A-Z -_]{2,}) ", r' \1 <allcaps> ')
    # Remove *
    df['text'] = df['text'].str.replace(r"\*", r'')

# %% [markdown]
# ### Split the TRAIN set into Train and Validate sets

# %%
xtrain_full = train_df['text']
xtest_full = test_df['text']
ytrain_full = train_df['target']
xtrain, xvalid, ytrain, yvalid = train_test_split(train_df.text.values, ytrain_full, 
                                                  stratify=ytrain_full, 
                                                  random_state=42, 
                                                  test_size=0.333, shuffle=True)

print(f'Train = {len(xtrain)} records\nValidate = {len(xvalid)} records')
# Out:
# Train = 5077 records
# Validate = 2536 records

# %%
print(f'Train data:\n {xtrain[0:1000]}')
# Out:
# Train data:
#  ['One Direction Is my pick for <url> Fan Army <hashtag> Directioners <url> x<number>'
#  'Wire<smile> Reddit Will Now Quarantine Offensive Content - Reddit co-founder and CEO <allcaps> Steve Huffman has unveiled more sp. <repeat> <url>'
#  "Next May I'll be free. <repeat>from school from obligations like family. <repeat> Best of all that damn curfew. <repeat>"
#  'Dem FLATLINERS <allcaps> who destroy creativity-balance-longevity  TRUTH <allcaps> stand with Lucifer in all his flames of destruction <url>'
#  'That usually NEVER <allcaps> happens'
#  "Russian nuclear-biological-chemical (NBC) <allcaps> brigade 'emergency response' exercise in Southern MD <allcaps> <url> <url>"
#  'IS claims suicide bombing against Saudi police: RIYADH (AFP) - <allcaps> An Islamic State group suicide bomber on Thursd. <repeat> <url>'
#  'My dad is panicking as my weight loss means he needs to hurry up with my new clothes fundwhen I reach my goal.  ? <allcaps> <repeat>'
#  " <user> All Andre and Gore have to do is not fall off the cliff and we're elite on that side of the ball."
#  ' <user> the first time i went swiming in it i was basically screaming WHY DOES IT SMELL/TASTE SO <allcaps> BAD'
#  'Christian Attacked by Muslims at the Temple Mount after Waving Israeli Flag via Pamela Geller - . <allcaps> <repeat> <url>'
#  '<number> Years After Atomic Bombs Japan Still Struggles With War Past <url> The anniversary of the devastation wrought by the\x89Û_'
#  'Crews were out all day boarding up windows at the park at the Galleria apts. where fire displaced <number> this AM. <allcaps> <url>'
#  'Japan Marks <number>th Anniversary of Hiroshima Atomic Bombing <url>'
#  '? <number>th Day Since <number>-Jul<number> -- <allcaps> Nigeria: Suicide Bomb Attacks Killed <number> People; Blame<smile> Boko Haram [L.A. <allcaps> Times/AP] | <url>'
#  'Damage to school bus on <number> in multi car crash <hashtag> BREAKING <allcaps> '
#  'PATRICK ROY <allcaps> <number><number> UPPER DECK SPX <allcaps> <hashtag> <number> FINITE <allcaps> <number> MADE COLORADO AVALANCHE MINT <allcaps> <url> <url>'
#  "ykelquiban: Breaking news! Unconfirmed! I just heard a loud bang nearby. in what appears to be a blast of wind from my neighbour's ass."
#  'I added a video to a  <user> playlist <url> Doc: Volcanoes and Earthquakes - Inside the Volcano'
#  'Passengers evacuated  lanes blocked off as power lines come down over a Gold Coast tram  <user> <url>'
#  'Alleged East Bay serial arsonist arrested <hashtag> SanFrancisco - <url>'
#  'Calgary area tornado warnings end as thunderstorms move eastward - CBC.ca: CBC.ca Calgary area tornado warnings end\x89Û_ <url>'
#  ' <user> Except when ordered not to carry unauthorized weapons while on duty or in military uniforms. THATS THE RULE <allcaps> FOOL'
#  'Morgan Silver Dollar <number> S Gem BU DMPL <allcaps> Cameo Rev Blazing MS+++++ <allcaps> High grade! - Full read \x89Û_ <url> <url>'
#  'The Most Generous Bride on Earth: Couple Feeds <number> Syrian Refugees on Their Wedding Day <url> via  <user> love it!'
#  'I want to go back to Vegas for my <number> but I feel like that would be such a disaster lol so much money would need to be brought'
#  'infected bloody ear piercings are always fun? <repeat>'
#  ' <user> oh shit!' "I'm feeling so attacked <url>"
#  'Ignition Knock (Detonation) Sensor-Senso Standard KS<number> <url> <url>'
#  '[infowars]  Nashville Theater Attack: Will Gun Grabbers Now Demand \x89ÛÏHatchet Control?\x89Û\x9d <url> <hashtag> nwo'
#  "Russian 'food crematoria' provoke outrage amid crisis famine memories <url>"
#  "nflexpertpicks: Michael Floyd's hand injury shouldn't devalue his fantasy stock: Michael Floyd's damaged digits won. <repeat> \x89Û_"
#  'Report: Corey Brewer was drug tested after <number>-point explosion <url>'
#  'I forgot to bring chocolate with me. Major disaster.'
#  'Governor allows parole for California school bus hijacker | Fresno Linked Local Network <url> <url>'
#  ' <user> I am an eyewitness HA'
#  'Ye did the same thing to Big Sean and he still blew up'
#  ' <user> Please check into Salt River horses help stop the annihilation about to happen without <number> more signatures.change .org Thx'
#  '<hashtag> Arsonist arrested for setting many fires. WATCH <allcaps> tonight\x89Ûªs other <hashtag> headlines: <url> <hashtag> Nightbeat  <user> <hashtag> <number>MinuteMix'
#  'Fuck  Neil go fall off a cliff or something. <repeat><hashtag> yr ? <repeat>'
#  'How many cars do those cyclists wreck going past scratching with pedals. They should be banned <hashtag> c<number>news'
#  'Lose bus card.\nPanic.\nKind bus driver.\nReplace bus card.\nFind bus card.\nHeaddesk.'
#  'Police: Arsonist Deliberately Set Black Church In North CarolinaåÊAblaze <url>'
#  "She just said does he have a curfew 'nope'? <repeat>"
#  "PHOTOS: The Rocky Fire has grown into California's most destructive wildfire this year. <url> <url>"
#  "<hashtag> NowPlaying 'The Lightning Strike' de Snow Patrol de A Hundred Million Suns ? <url>"
#  '<number>-day bug in fully patched OS X <allcaps> comes under active exploit to bypass password . <repeat> - Ars Technica <url>'
#  "I ran with earbuds in which I now realize means I probably didn't politely say hi to Jared but more or less screamed at him ? <repeat>"
#  'I just bought tickets to DEATH BED / DUDE BRO PARTY MASSACRE I <allcaps> <elong> w/  <user> Live at  <user> <url>'
#  ' <user>  <user>  the stat of high auto deaths applies to children in a vehicle. I guess they can out run lightrail better than adult'
#  'Quality Metrics Penalties May Harm Patient Care PCPs Say: Primary care physicians generally hold positive vi. <repeat> <url>'
#  'Refugio oil spill may have been costlier bigger than projected <url>'
#  'Army sources say <number> persons on board including a team of doctors die in helicopter crashed near Mansehra. weather seems to be cause of crash'
#  "'I came to kill Indians. <repeat>for FUN': <allcaps> Video of smirking and remorseless Pakistani killer shows him boasting. <url>"
#  'Megadeth Week - Symphony Of Destruction <url>'
#  'Vote for <hashtag> Directioners vs <hashtag> Queens in the <number>th round of the  <user> <hashtag> FanArmyFaceOff <url>'
#  'Block the plate with a charging Schwarber coming down the line Cervelli. I dare you. You would explode into a little puff of smoke'
#  "I have my final tomorrow ? <repeat> . Ish is stressful  but I'll survive"
#  '<number> police officers arrested for abusing children at police-run boot camp in San Luis Obispo Calif. -  <allcaps> <user> <url>'
#  ' <user>  <user> <hashtag> wish Mattingly  Bundy  McGwire were standing on it when it collapsed!'
#  "when you don't know which way an ambulance is coming from "
#  " <user> Any idea what's going on? I hear no sirens but this damn helo is flying so low my apt is shaking!"
#  ". <user> true. I faced everything from 'Is Bin Laden your uncle?' to 'Hopefully Afghanistan will be bombed'. Children can be very ugly."
#  'Lol meerkat is fucked. They will get demolished by periscope and Facebook live streaming.'
#  " <user>  <user> I remember now.  There was a British man who survived both also.  Can't remember his name though."
#  'Global Nuclear Reactor Construction Market grew <number>% between <number> and <number> <url>'
#  'My Dad a screaming coach always gave his vocal chords quite the workout on the field. <url> <hashtag> FunnyDadCoach'
#  ' <user> jay. <repeat>big L. <allcaps> <repeat>pun. <repeat>biggie. <repeat>wrap over. <repeat>zero question. <repeat>fatality. <repeat>flawless victory <url>'
#  "it's <number> and I'm already panicking and crying bc I'm so stressed NICE"
#  "'What we perceive burns faintly like a sputtering candle before the vast desolate glacier of Eternity'\n\n-Sister Gyrsi"
#  'A Santa Ana Police Union Blocks Video of the Raid at Sky High Holistic Pot Dispensary - The Atlantic <url> <hashtag> SmartNews'
#  ' <user> <hashtag> FETTILOOTCH IS <allcaps> <hashtag> SLANGLUCCI OPPRESSIONS GREATEST DANGER COMING SOON THE ALBUM <allcaps> \n<url>'
#  'Is there a night curfew on campus?\n\nFind out here: <url> <url>'
#  'SMH photographer Wolter Peeters was on the front line with NSW <allcaps> Rural Fire Service crews la\x89Û_ <url> <url>'
#  '<hashtag> Lifestyle \x89Û÷It makes me sick\x89Ûª: Baby clothes deemed a \x89Û÷hazard\x89Ûª <url> <url>'
#  'Crptotech tsunami and banks.\n <url> <hashtag> Banking <hashtag> tech <hashtag> bitcoing <hashtag> blockchain'
#  'Police Officer Wounded Suspect Dead After Exchanging Shots - <url>'
#  ' <user> Arrest report: Affiliation with Terrorism'
#  '<hashtag> RolandoNaBeats: Ellie Goulding - My Blood | Acesse nosso site para ouvir! <url>'
#  '{:en}Tension In Bayelsa As Patience Jonathan Plans To Hijack APCåÊPDP{:} <url> <url>'
#  " <user> they can't detonate unless they touch the ground"
#  '<url> Osage Beach releases name'
#  'Build and share your own custom applications all within  <user> w/ TC <allcaps> Exchange  <url> <hashtag> infosec <hashtag> DFIR <allcaps> <hashtag> ThreatIntel'
#  ' <user> GM! I <allcaps> pray any attack of the enemy <number> derail ur destiny is blocked by the Lord  that He floods ur life w/heavenly Blessings'
#  ' <user> shout out blaze the hottest DJ <allcaps> in the Sothwest'
#  ' <user> Nearly-Fatal Pee in San Francisco <url>'
#  'Casualty Roleplay somebody please am so bored'
#  "'Seeing that there's a video of every fatality on Mileena makes me sad.'"
#  'Medieval airplane hijacker hard shell: casting the star deviating: dYxTmrYDu'
#  'News<number>-UK Islamist Cleric Anjem Choudary Charged Under Terrorism Act: <url>'
#  "I presume my timeline will be inundated with 'soggy bottom'  lashings of 'moist' tweets now! <smile>"
#  'Ignition Knock (Detonation) Sensor ACDelco GM <allcaps> Original Equipment <number><number> <url> <url>'
#  'Falling asleep to the sounds to thousands of River Plate fans in the stadium and a thunderstorm. <hashtag> VivaArgentina'
#  ' <user> did the First World War Ever Truly End? The Ripples Are With Still and have been compound into low level Tsunami'
#  ' <user>  <user> we are cuddling right now so. <repeat> ? <repeat>'
#  'holy crap  <user> my phone just exploded. haha'
#  'Photographer Brian Ruebs endures <number>-feet climb to capture bride and groom <url>'
#  'Three Homes Demolished in Unrecognized Arab Village - International Middle East Media Center <url>'
#  'New! Stretcher in <number> min <url> (by FUJIWARA <allcaps> Shunichiro <number><number><number>) [Technology]'
#  ' <user>  <user> THUNDER <allcaps> BUDDYS!'
#  '<number> <hashtag> Earthquake in Sicily Italy <hashtag> iPhone users download the Earthquake app for more information <url>'
#  ' <user>  <user> Can you hear me screaming ! <repeat>'
#  "When you're in deep sleep and then you dream you're bout to fall off a cliff then wake up while struggling to keep a balance"
#  'When I breathe it sounds like a windstorm. Haha cool'
#  'How much would it cost to have some fat displaced? Asking for a friend.'
#  '<hashtag> golf McIlroy fuels PGA <allcaps> speculation after video: Injured world number one Rory McIlroy fueled speculatio. <repeat> <url> <hashtag> news'
#  "<hashtag> veterans VET <allcaps> Act would ensure every military veteran's access to highest level of emergency care services: Proper treatmen. <repeat>  <hashtag> followme"
#  "'Go too Ibiza Pop ah Pill Get DRUNK  <allcaps> Fall off a Cliff'. (Real Talk)  <user>  <user>  <user>"
#  "[FORBES]: China's Stock Market Crash: Are There Gems In The Rubble?: China\x89Ûªs stock market crash this summer ha. <repeat> <url>"
#  ' <user> Trauma Center Shines In Response To Multi-Casualty Crash. <url> <url>'
#  ' <user>  <user> I am surprised we still cannot standardised the clinical practice across the <number> NHS <allcaps> ambulance trust.'
#  'Lake Dallas crash causes train to derail <url>'
#  " <user> I never thought it would be a wtf moment yet it's here after months of <number> degree heat\nNext we will have flash floods. <repeat>"
#  'London is cool <smile>'
#  " <user> It's not an 'impulse' and it doesn't end in mass murder. Correlation does not imply causation."
#  ' <user> Torrecilla We Always info the Secret on LoL Game Check the Secret to get <number> Riot Points on my Bio'
#  'Trusting Iran to stop terrorism is like inviting an arsonist to join the fire brigade - Telegraph <url>'
#  "'I may have gotten a little too exited over my (home made) lava lamp.':<url> <url>"
#  "It's kinda cool tonight. Is the heat wave finally over? <repeat> ? <repeat> <number>amdollela <number>la kulli <number>aal"
#  'How to Remove Softenza Hijacker? Softenza Anthelmintic Nature book Drawing out Help SEA'
#  "TTW Today's News: Bin Laden family plane crashed after 'avoiding microlight and landing too far down runway'  <url>"
#  'brooke just face timed me at the concert and just screamed for <number> minutes straight'
#  "someone's gonna get screamed at for getting the lyrics wrong lmao"
#  'Anti Collision Rear- <hashtag> technology <hashtag> cool <url> Via Techesback <hashtag> Tech'
#  'when you are quarantined to a little corner bc you are too sick to be in the office but work is piling up and they need you kinda day'
#  'Photoset: hakogaku: ?åÊI am a kurd. i was born on a battlefield. raised on a battlefield. gunfire sirens. <repeat> <url>'
#  " <user> me  you both  I'll be dam if I get any of that drought bud"
#  'Canceling Deal for <number> Warships <hashtag> France Agrees to Repay <hashtag> Russia via  <user> <url>'
#  ' <user> Yeah you are! <hashtag> SpeakingFromExperience'
#  'Six people were killed Thursday when a Taliban suicide bomber detonated an explosives-rigged truck outside a police compound in eastern'
#  'Truly a scene of chaos unprecedented in frenzy. Pandemonium even. Utter disorder. That anyone survived such mania is astounding.  <user>'
#  "I still don't know why independence day and social casualty are not on the rowyso setlist these songs would be so good live"
#  " <user> you better make all your shots tomorrow cause I'm recording and flames will be thrown tomorrow"
#  'Afghanistan: sharp rise in women and children casualties in first half of <number> <url>'
#  'someone just reblogged a picture of self harm scars oh please its <number> can we stop'
#  " <user>  <user>  <user>  <user>  <user> It's not pretty ? <repeat><hashtag> disaster <hashtag> GBBO <allcaps> <hashtag> mudslide"
#  'August <number> Your daily horoscope: A relationship upheaval over the next few months may be disruptive but in the . <repeat> <url>'
#  'If a nigga was a threat then that boy ah be thru ? <repeat>'
#  "Training grains of wheat to bare gold in the August heat of their anger I'm the no trespass lest you seek danger."
#  'Spot fixing/match fixing . <repeat>anyone? <repeat>\nOr it has to be Pak SL WI RSA <allcaps> or BD <allcaps> to say this. Sham on them who say that when these team collapse'
#  'The number of people denying climate change on the polar bear article makes me fear for the future of the US <allcaps> but also humanity in general.'
#  "THE GIRLS NEXT TO ME SCREAMED WHAT THE FUCK IS A CHONCE <allcaps> I'm CRYIBG"
#  'Marley Brinx gives a striptease and then spreads her legs for a pussy pounding <url> View and download video'
#  "I'm not the mom friend but I still see my friends as my little babies that I have to care for or else they'll electrocute themselves"
#  'Officer wounded suspect killed in exchange of gunfire: Richmond police say an officer has been wounded and a . <repeat> <url>'
#  "on the outside you're ablaze and alive\nbut you're dead inside"
#  'FYI: ;ACCIDENT PROPERTY <allcaps> DAMAGE;<number> LIMESTONE LN;COL;YELLOWSTONE WAY;FIELDSTONE <allcaps> DR;<number>/<number>/<number> <number>'
#  ' <user> for the <hashtag> international emergency medicine conference w/ Lennox Hill hospital and <hashtag> drjustinmazur'
#  'The gusto in persist had amongst empty-pated communication explosion: hPSsJD'
#  'When a real nigga hold you down you supposed to drown'
#  'Some older Native Australians believe that the oceans were created from the urine of an angry god who tried to drown the world.'
#  ' <user> It is almost amazing to think someone thought suicide bombing would actually be a good idea.'
#  'Heavy smoke pouring out of buildings on fire in Port Coquitlam <url> <url>'
#  "Fukushima 'mutant vegetable' images sweep across the region two years after nuclear disaster <url> via  <user>"
#  'Two cranes restoring a bridge in the central Dutch town of Alphen aan den Rijn collapse on to buildings with rescuers searching for'
#  '--thus making  <user> assault useless.\nThe spears collided with the dark force however did not penetrate.\n\nDue to the dark --'
#  'Early wake up call from my sister begging me to come over  ride w/her in the ambulance to the hospital <hashtag> RODKiai'
#  "OMG NIXON LIVES! <allcaps> That is Richard M. <allcaps> Nixon Tricky Dicky right there in the picture isn't it. Hiding in Calgary he. <repeat> <url>"
#  " <user> the whole city is trapped! You can't leave the city! This was supposed to be a normal sports manga wit a love triangle (c)"
#  'Trafford Centre film fans angry after Odeon cinema evacuated following false fire alarm <url> <url>'
#  "The Prophet (peace be upon him) said 'Save yourself from Hellfire even if it is by giving half a date in charity.'"
#  'Thunderstorm in Helsinki\n<hashtag> thunder <hashtag> lightning <hashtag> lightningstrike <hashtag> thunderstorm <hashtag> nature <hashtag> Helsinki\x89Û_ <url>'
#  'Time to obliterate this sin!'
#  "Marketforce Perth named winner of Sirens round <number> for 'iiNet NBN <allcaps> Buffering Cat Shark' radio spot <url>"
#  ' <user> if you follow me I will go into town and advertise your youtube channel by screaming and walking around with a sign. Pls? <repeat>'
#  "December <number> court dismissed the group charge of rape victims saying 'getting raped was an occupational hazard! <repeat>'\n\nUS military = ISIS!"
#  'Deal of The Day : <url> Brand New DSERIALPCILP <allcaps> Lava Computer PCI <allcaps> Bus Dual Serial <number> Board  <hashtag> e\x89Û_ <url>'
#  'Foto: \x89ÛÏLove isn\x89Ûªt everything to me anymore. The last album I made [Red] was a devastated record because. <repeat> <url>'
#  ' <user>  <user> photo bombed'
#  'Dorman <number><number> Ignition Knock (Detonation) Sensor Connector <url> <url>'
#  '? <repeat> New Ladies Shoulder Tote <hashtag> Handbag Faux Leather Hobo Purse Cross Body Bag <hashtag> Womens <url> <url>'
#  'Fire burning on Pendleton has burned <number> acres: Smoke reported drifting over Temecula. <url>'
#  ' <user> there are a few reasons for that but one of them is the constant Drake inundation.  Extremely annoying.  If Drake lands us a'
#  'Jeep Cherokee Owners File Lawsuit Against Fiat Chrysler Harman After Hackers . <repeat> - The Consumerist <url> <hashtag> mcgsecure'
#  'SpaceX Founder Musk: Structural Failure Took Down Falcon <number> <url>'
#  'Transportation panel showing a video of a pileup of <number>-wheelers in a snowstorm in WY. <allcaps> Crash crash crash \x89ÛÏMake it stop!\x89Û\x9d <hashtag> AMSsummer'
#  '<number> Years After Atomic Bombs Japan Still Struggles With War Past: The anniversary of the devastation wrought b. <repeat>  <url>'
#  "Drunk Meals <number> What To Cook When You're Totally Obliterated <url>"
#  'Rory McIlroy to Test Ankle Injury in Weekend Practice <hashtag> chinadotcom <hashtag> sports <url> <url>'
#  'Today was trauma on top of trauma on top of  trauma in Richmond so I know work is going to be crazy the next two days'
#  "Wreckage 'Conclusively Confirmed' as From MH<number> Malaysia PM: <allcaps> Investigators and the families of those who were. <repeat> <url>"
#  'Multiple Buildings On Fire In Downtown Hinton <url> <url>'
#  ' <user> craving u'
#  '<number>-Month-Old Baby Girl was Rescued by Coastguard after She Floated HALF A MILE <allcaps> Out to Sea! <hashtag> socialnews <url>'
#  'Emergency responders prepare for chemical disaster through Hazmat training. <url>'
#  ' <user>  <user> Thanks! I know you all get inundated. Have a good one!'
#  ' <user> I guess I can say you and me might have one thing in common my biological father made me this way to be his weapon'
#  'Man Cam just demolished his plate. His ass was hungry'
#  ' <user> GIVE ME FREE ART <allcaps> KAMON'
#  "<hashtag> gunsense answer to <hashtag> GFZ's: break law on the minuscule chance a mass murderer shows up. <url>"
#  "HIS MAJESTY EMPEROR SALMAN KHAN'S UNSTOPPABLE CYCLONE OF ENTERTAINMENT <allcaps> HUMANITY\nBAJRANGI BHAIJAAN CREATING HISTORY EVERYWHERE <allcaps> \nCROSED <number> CR"
#  "Families to sue over Legionnaires: More than <number> families affected by the fatal outbreak of Legionnaires' disea. <repeat> <url>"
#  'Salvation Army hosts rally to reconnect fathers with children: The Salvation Army is hosting a back to school rally\x89Û_ <url>'
#  'My biggest fear is disappointing the people who believe in me'
#  "The Prophet (peace be upon him) said 'Save yourself from Hellfire even if it is by giving half a date in charity.'"
#  'Pandemonium In Aba As Woman Delivers Baby Without Face (Photos) - <url>'
#  'Rise up like a natural disaster we take the bat and then we take back the town? <repeat>'
#  "Mum's literally just picked up her new car today and flattened the battery already trying to sort out the Bluetooth ? <repeat> <hashtag> Muppet"
#  'Police investigating after an e-bike collided with a car in Little Portugal. E-bike rider suffered serious non-life threatening injuries.'
#  'Asbury Park shooting reported <url> via  <user>'
#  "Wreckage 'Conclusively Confirmed' as From MH<number> Malaysia PM: <allcaps> Investigators and the families of those who were. <repeat> <url>"
#  ' <user> I predict a riot.'
#  'Illinois Tornado Slipped Under The Radar Emergency Officials Say <url>'
#  'Tomorrow is the day we start armageddon <hashtag> preseasonworkouts ? <repeat>'
#  'Marlon Williams  Elvis Presley  Marlon Williams  Steel Panther. \n\nShuffle mode like a bloody legend.'
#  '<hashtag> Sinjar Massacre <hashtag> Yazidis Blast Lack of Action Over Hostages <url> Portland <hashtag> Phoenix <hashtag> Newyork <hashtag> Miami <hashtag> Atlanta <hashtag> Casper <hashtag> Iraq'
#  'This Looney Tunes-Blake Griffin commercial screams their making a Space Jam <number>'
#  'My woman crush wedneday goes to the beautiful  <user> <hashtag> loveyou <elong> <hashtag> aintsheperty <url>'
#  'Visting Georgina at The Drowned Rat Cafe. <repeat>awful view! <repeat> <url>'
#  'Quick Fact: No <hashtag> nuclear reactor has come into operation in the <hashtag> US <allcaps> for over <number> years.  <url>'
#  '<hashtag> Japan <hashtag> Fukushima the most serious man made disaster in human history. <repeat>  \x89ÛÏa marker of radiation brain damage\x89Û\x9d <url>'
#  'Summer <hashtag> summervibes <hashtag> california <hashtag> puppy <hashtag> pitmix <hashtag> rescued <hashtag> brixton <hashtag> banksy <hashtag> happy <hashtag> mybabies <url>'
#  'Nearly <number> years after their release from captivity legislation is being introduced in Congress to compensate <number>\x89Û_ <url>'
#  'Richmond police officer wounded suspect killed <url>'
#  '<hashtag> SanDiego <hashtag> News Sinkhole Disrupts Downtown Trolley Service: The incident happened Wed. <repeat> <url> <hashtag> Algeria <hashtag> ? <repeat>'
#  'Escaping her captors was the <number>st step. Now she must survive a deadly storm  a wild-looking recluse.\nBETRAYED\n<url>\n<hashtag> books'
#  '(OK)  Severe Thunderstorm Warning issued August <number> at <number>PM CDT <allcaps> until August <number> at <number>PM CDT <allcaps> by NWS <allcaps> <url> <hashtag> okwx'
#  '<number>-Year-Old Boy Charged With Manslaughter of Toddler: Report: An <number>-year-old boy has been charged with manslaughter over the fatal sh. <repeat>'
#  'The Latest: More Homes Razed by Northern California Wildfire - ABC <allcaps> News <url> <hashtag> GN'
#  'The Cafe Run by Acid Attack Survivors in <hashtag> India <url> <url>'
#  ' <user> I AM BEING SUBJECTED TO UNWARRANTED SEXUAL <allcaps> CONVERSATION.'
#  'Twelve feared killed in Pakistani air ambulance helicopter crash - Reuters <url> <hashtag> yugvani'
#  'Louis Vuitton Monogram Sophie Limited Edition Clutch Cross body Bag - Full read by eBay <url> <url>'
#  "I can't believe Blevins got injured falling off a curb. That's something that would happen to me never it expected for a pro player"
#  'I liked a  <user> video <url> Minecraft: NIGHT LUCKY BLOCK MOD (BOB APOCALYPSE WITHER <allcaps> <number>  MORE!) <allcaps> Mod Showcase'
#  "They sky was ablaze tonight in Los Angeles. I'm expecting IG <allcaps> and FB <allcaps> to be filled with sunset shots if I know my peeps! <repeat>"
#  'Refugio oil spill may have been costlier bigger than projected (LA <allcaps> Times) <url>'
#  'The Murderous Story Of America\x89Ûªs First Hijacking <url>'
#  'This is why I am scared to leave my car under trees in a storm\n\n<hashtag> jamaicaplain <hashtag> boston <hashtag> hailstorm\x89Û_ <url>'
#  'Fire crews evacuate passengers from a Gold Coast tram trapped when powerlines fell across a carriage. <hashtag> TenNews <number>pm <url>'
#  'iCASEIT - MFi Certified Lightning Cable - <number>m <url> <url>'
#  '<hashtag> ? <repeat> <hashtag> ? <repeat> <hashtag> ? <repeat> <hashtag> ? <repeat> MH<number> Aircraft debris found on La Reunion is from missing Malaysia Airlines . <repeat>  <url>'
#  'School Bus Hijacker Given Parole After <number> Years <url>'
#  "I'm crying that song just ended setting myself on fire  <url>"
#  "Parents are taking their kids to Burning Man and one <number> year old thinks it's 'better than. <repeat> <url>"
#  "Neil_Eastwood<number> I AM A KNOBHEAD! <allcaps> <repeat> Bin Laden family plane crashed after 'avoiding microlight and landing t. <repeat> \x89Û_ <url>"
#  " <user> Nothing wrong with that. The Lethal Weapon series is great. Yes they're ALL <allcaps> great."
#  'fatality'
#  'When Houston and NYC <allcaps> collide. ? <repeat>  <user>  <user>  <user>  <user>  <user> <hashtag> gemma <hashtag> bowe\x89Û_ <url>'
#  'Finnish ministers: Fennovoima nuclear reactor will go ahead <url> <hashtag> worldnews <hashtag> news <hashtag> breakingnews'
#  "Paul Rudd Emile Hirsch David Gordon Green 'Prince Avalanche' QA <allcaps> | Filmmakers at Google <url>  <hashtag> entretenimento <hashtag> Video"
#  'Sinkhole Disrupts Downtown Trolley Service <hashtag> SanDiego - <url>'
#  'I see dat we liable to fuck up and crash ? <repeat>'
#  'Bluedio Turbine Hurricane H Bluetooth <number> Wireless Stereo Headphones Headset BLK - <allcaps> Full re\x89Û_ <url> <url>'
#  ' <user> so destruction it seems. I see myself ruined. <repeat> somehow.'
#  'Owner of Chicago-Area Gay Bar Admits to Arson Scheme <url> via  <user> <hashtag> LGBT'
#  'Blending the old with the new in <hashtag> Vanuatu to prepare for future emergencies: \n<url> <url>'
#  ' <user> Yo Dm me'
#  "When you're girlfriend is completely gorgeous? <repeat> @ woman crush  stuff <url>"
#  'Selection September Bridgeport men charged in home invasion Police looking for burglar. - <url>'
#  'MP trains derailment: \x89Û÷It\x89Ûªs the freakiest of freak accidents\x89Ûª: \n\nMP trains derailment: \x89Û÷It\x89Ûªs the freakiest of . <repeat> <url>'
#  'Suicide bomber kills <number> in Saudi security site mosque  <hashtag> world <hashtag> news'
#  'RT  <user> Likened to THE <allcaps> <number> STEPS <allcaps> and The GOOD SHEPHERD <allcaps> by the FILM <allcaps> producer THE DESOLATE GARDEN <allcaps> on ALL <allcaps> here  <url>'
#  'The Bush fires in CA <allcaps> are so crazy'
#  'Flooding kills <number> displace over one million in Pakistan - Daily News  Analysis <url>'
#  'The Murderous Story Of America\x89Ûªs First Hijacking <url>'
#  '<hashtag> foodscare <hashtag> offers<number>go <hashtag> NestleIndia slips into loss after <hashtag> Magginoodle <hashtag> ban unsafe and hazardous for <hashtag> humanconsumption'
#  "Why does my phone electrocute me when it's charging"
#  'i decided to take a break from my emotional destruction to watch tangled then watch desolation of smaug'
#  'AUTH LOUIS VUITTON BROWN SAUMUR <allcaps> <number> CROSS BODY SHOULDER BAG MONOGRAM <allcaps> <number> <number><number> - Full read\x89Û_ <url> <url>'
#  'Calgary Transit reviewing policy after leaving hundreds of commuters stranded during hail\x89Û_ <url> <url>'
#  'British diver Neil Anthony Fears found dead by the wreck of a steamship - Daily Mail <url>'
#  'Brain twister homefolks are opinionated over against proposal modernized canada: oMw'
#  " <user> i be seen them turn a blind eye to a bloke drinking and smoking on during the curfew time cos'its not worth the hassle'"
#  " <user>  <user> if you think you'd like burning man you should try it because it's the only way to know!"
#  " <user>  <user> Climate Change CNN <allcaps> weather 'specialist' warning:wild fires rain flooding noting about the sun? <url>"
#  '. <repeat>the kids at the orphanage were obviously not too traumatised. <url>'
#  "So Pardon me while I burst into flames. \n\nI've had enough of the world and its people's mindless games"
#  'A blizzard would be clutch asf ? <repeat>'
#  'ABC News: Police Officer Wounded Suspect Dead After Exchanging Shots. More <hashtag> news - <url>'
#  'Blood Group  A <allcaps> +ve is associated with Gastric Carcinoma says text book. <repeat>Another fragile gene in my body. <repeat>'
#  'September <number> Defeater at the Epicentre hell yeaahh'
#  'Udhampur terror attack: Militants attack police post <number> SPOs injure<smile> Suspected militants tonight attacked a p. <repeat> <url>'
#  "Apparently they're going to have a WW<number> siren to announce something. Not sure if that's fun or dull bc the WW<number> siren is a v monotonous sound."
#  'Arsonists being blamed for a blaze at a plastics recycling business in Adelaide |  <user> reports. <hashtag> <number>NewsAdl <url>'
#  " <user> whoever holds the address 'fuckface <user> is going to be deluged in spam meant for me"
#  " <user>  <user> \n'The Exploded - Bean the Bastard'"
#  'why are people panicking about results day though hahahah like worrying is going to change your results'
#  ' <user> your lifetime odds of dying from an airplane accident are <number> in <number>'
#  '! Residents Return To Destroyed Homes As Washington Wildfire Burns on <url>'
#  " <user> click on the tag there's lots of them. RT <allcaps> them to hijack the hashtag"
#  'rgj: Truck trailer catches fire in Reno <url>'
#  " <user> No worries you'd have to be on every hitters most pitchers got destroyed"
#  'BBC Forced To Retract False Claims About Cyclone Pam <url> via  <user>'
#  'Blazing Hot! Etisalat Free MB <allcaps> For Complete <number> Months: Etisalat Is Giving out <number>MB on TECNO <allcaps> Q<number> here is the Ime. <repeat> <url>'
#  " <user>  <user> Looks like a bowl of weather cereal. New! Kellogg's Sugar Hail! Stays crunchy even in milk. <repeat>"
#  'Flood Advisory in effect for Shelby County in AL <allcaps> until <number> PM <allcaps> <hashtag> alwx <url>'
#  "Drake spokes rep for the raptors.Beg to differ the other night when shots rang out at Musik wasn't a goodlook.Running in panic no fun"
#  "Map shows where all of California's wild<hashtag> fires are burning: This map created by CAL <allcaps> FIRE\x89Û_ <url> <url>"
#  ' <user>  <user> also me please I would very much like a link'
#  ' <user> Govt should pass the bills in the Pandemonium. UPA <allcaps> used to do it why cant NDA?'
#  'I love fruits'
#  'Reddit Will Now Quarantine Offensive Content: Reddit co-founder and CEO <allcaps> Steve Huffman has unveiled more specif. <repeat> <url>'
#  'Hellfire is surrounded by desires so be careful and don\x89Ûªt let your desires control you! <hashtag> Afterlife'
#  'Did anyone else see that fireball falling to earth? Look like a plane blew up.'
#  "If your friends really were your friends they'd support you regardless of your decisions.\n\nUnless you become a mass-murderer or something"
#  'Cancers equate for around <number>% of all deaths in <hashtag> Blackpool. \n\nKowing the signs could save your life: <url>\n<hashtag> BeClearOnCancer'
#  "It's a miracle that mankind survived <number> years since one of the worst days in its history. All bets are off if it will survive the next <number>"
#  '[GPV Wind] As of <number>JST <number>AUG: WNW <allcaps> <number>JST <number>AUG / E <allcaps> <number>JST <number>AUG / S <allcaps> <number>JST <number>AUG. <url>'
#  'Enugu Government to demolish illegal structures at International Conference Centre: Enugu State government app. <repeat> <url>'
#  "I still don't know how <number> hours of physical activity in the blazing sun isn't a sport."
#  "I feel that 'crash and burn' by Thomas Rhett for sure"
#  '[Report <number>] <number> Ibaraki Prefecture offing M<number> Depth <number>km Maximum seismic intensity <number> <hashtag> Earthquake'
#  'If you sit and rant on snapchat to your apparent fans when you have about <number> followers I hope your in a train crash xoxo'
#  'When your heart is bigger than the obstacles  in front of you <hashtag> euro <hashtag> dontexpectnothing <hashtag> july <hashtag> fire  <user>'
#  'RT  <user> Reddit will now quarantine offensive content <url>'
#  'ML <number> SICILY ITALY <allcaps> <url> <hashtag> euroquake'
#  ' <user>  <user>  <user>  <user>  <user> why you screamed'
#  ' <user>  <user> Did you get wrecked again?'
#  '<hashtag> Rohingya houses in <hashtag> Kyee NockThie hamlet from Taungbazar region in Buthidaung were severely damaged in Cyclone  <user>  <user>'
#  'President Barack Obama has on air meltdown over opposition to Iran nuclear deal <url> via  <user>'
#  'New Ladies Shoulder Tote Handbag Faux Leather Hobo Purse Cross Body Bag Womens - Full read\x89Û_ <url> <url>'
#  'to Luka They should all die! All of them! Everything annihilated! - Alois Trancy'
#  'JAX issues Hazardous Weather Outlook (HWO)  <allcaps> <url> <hashtag> WX'
#  '<hashtag> breaking <hashtag> LA <allcaps> Refugio oil spill may have been costlier bigger than projected <url>'
#  'California oil spill might be larger than projecte<smile> <url> <url>'
#  "'California's Burning:' Gov. on Drought Wildfires <url>"
#  '<number> Mercury Cyclone GT <allcaps> Quarter Panel D/S <allcaps> Rear Trim Moulding Cobra Jet <number>CJ <url> <url>'
#  'See a virtual tour of one of our listings on <number> Fir St Cannon Beach OR <allcaps> listed by Dorrie Caruana. <url>'
#  'Element of Freedom: The Biggest Party of the Summer @ Mirage Saturday! Tickets at <url>'
#  ' <user> i hope that mountain dew erodes your throat and floods your lungs leaving you to drown to death'
#  'Stemming from my <hashtag> Cubs talk- the team rosters <number> cancer survivors in  <user>   <user> fans: help another <url>'
#  "Stay tuned or don't idc <hashtag> casualties <url>"
#  "A protest rally at Stone Mountain? Atleast they're not burning down buildings and looting store like some individuals do when they 'protest'"
#  "'Mages of Fairy Tail. <repeat> Specialize in property damage!' - Natsu Dragneel"
#  'Factors to Consider When Hiring a Demolition Company nOxDV'
#  'There some flash flooding in madison <hashtag> valleywx'
#  'Maj Muzzamil Pilot Offr of MI<number> crashed near Mansehra today. <url>'
#  "'There is no victory at bargain basement prices.' Dwight David Eisenhower"
#  'Womens Buckle Casual Stylish Shoulder Handbags Pockets Cross Body Bags White <url>'
#  "' <user> <number> @ your bf/gf/crush ? <repeat>'  <user> ? <repeat>"
#  'Man! What I would give to be in CA <allcaps> right now to help with the wild fires.'
#  'Christian Attacked by Muslims at the Temple Mount after Waving Israeli Flag via Pamela Geller - . <allcaps> <repeat> <url>'
#  '<number> Charts Prove Financial Crisis Part <number> Has BEGUN!: <allcaps> The Financial Armageddon Economic Collapse Blog tracks tren. <repeat> <url>'
#  'Pakistan Supreme Court OKs Military Courts to Try Civilians: The Supreme Court ruling would empower the milita. <repeat> <url>'
#  " <user>  <user> That or they might be killed in an airplane accident in the night a car wreck! Politics at it's best."
#  'Buyout Giants Bid To Derail å£<number>bn Worldpay IPO <allcaps> \x89ÛÒ SkyåÊNews <url>'
#  ' <user> Have you been held hostage?'
#  '<hashtag> LakeEffect <hashtag> Snowstorm Twill Denim Jackets    ALL MY PROCEEDS FOR ITEMS WITH THIS DESIGN WILL <allcaps> GO\x89Û_ <url>'
#  'DLH issues Hazardous Weather Outlook (HWO)  <allcaps> <url> <hashtag> WX'
#  'Homemade frozen yogurt pops? Have you had luck making them? <url> <url>'
#  'SCREAMS AT MY OWN MOTHER <allcaps> <url>'
#  "Elsa is gonna end up getting electrocuted. She's gonna end up like that cat from christmas vacation."
#  'FUCK NUCLEAR <allcaps> WEAPON'
#  'Large sinkhole swallows entire pond in Lowndes County Georgia <url> <hashtag> YoNews'
#  'Remove the <url> and Linkury Browser Hijacker <url> <url>'
#  'Thank you so so much to everyone for posting the rain and hail outside . <repeat> I had no idea guys ? <repeat>'
#  ' <user>  <user> I just saw these tweets and I feel really attacked'
#  ' <user> my personal favorites include paramore muse green day royal blood and <number>sos'
#  'As soon as maintenance ends everyone floods the servers\nServers destroyed by extreme load\nMaintenance starts anew'
#  ' <user>  <user> my ig is being blown up just with hackers I need it to stop <hashtag> givebackkalinwhiteaccount'
#  'Wed <number> Mainly cloudy. <number> percent chance of showers this evening with risk of a thunderstorm. Low <number>'
#  ' <user> I trickshot with a regular controller fucking infinite fading is so harm <sadface>'
#  'The Lightning out here is something serious!'
#  ' <user>  <user> I seen Judas Priest in <number> when Rob came back; Scorpions as support. Fucking annihilated the place. Astonishing gig'
#  ' <user> Thorgan Hazard made his move permanent go Gladbach this summer lmao'
#  ' Screams ' 'Flooding ? <repeat> <url>'
#  "I'm my own woman crush ? <repeat>"
#  'I liked a  <user> video from  <user> <url> DJ <allcaps> Hazard - Death Sport'
#  'Dying with debt can be costly for survivors'
#  'Large fire burning several buildings causing evacuations in downtown Hinton: <url>'
#  'Diego Costa needs to stop getting injuries urg'
#  'Im so anxious though because so many ppl will me watching me meet them and that makes me uncomfortable BUT I CANT LET THAT RUIN THE <allcaps> MOMENT'
#  'The Architect Behind Kanye West\x89Ûªs Volcano <url>'
#  '<hashtag> Breaking<number> Obama Declares Disaster for Typhoon-Devastated Saipan: Obama signs disaster declarat. <repeat> <url> <hashtag> AceNewsDesk'
#  'I should probably stay away from hot glue guns. <repeat> I burned one finger pretty bad'
#  'That hellfire song from the hunchback of notre dame reminds me a lot of my house'
#  ' <user> I hope you drown ? <repeat>'
#  'Bigamist and his \x89Û÷first\x89Ûª wife are charged in the deaths of his \x89Û÷second\x89Ûª pregnant wife her child <number> her mother her nephew <number> and their u\x89Û_'
#  '<hashtag> Saudi Arabia: <hashtag> Abha: Fatalities reported following suicide bombing at mosque; avoid area <url>'
#  'I have never screamed so loud <url>'
#  " <user>  He's already done it by negotiating with the <hashtag> <number> state of terrorism in the World. What was his hurry in trying to get a deal"
#  'can still see it. <repeat>blank expression. <repeat>cheeks clapping in my face. <repeat>marvins room playing subtlety in the back yet drowning out all the sound'
#  ' <user> SCREAMING'
#  'The Latest: <hashtag> Wildfire destroys more homes but crews advance - WQOW TV <allcaps> News <number> <url>'
#  'This is the natural and unavoidable consequence of socialism everywhere it has been tried.\n<url> A'
#  'NEW Snap On Tools Black baseball Hat/Cap Silver/Gray Embroidered S Logo Flames - Full re\x89Û_ <url> <url>'
#  'Do you feel engulfed with low self-image? Take the quiz: <url> <url>'
#  'I found a diamond in the rubble'
#  "When the answer my friend isn't blowing in the wind-IT'S YELLING! <allcaps> -How to Survive a Dust Storm <url> <url>"
#  "<hashtag> Russia 'food crematoria' provoke outrage in country w/soaring poverty +Soviet famine memory <url> <url>"
#  ' <user> This has opened up old baked alaskan shaped wounds. Too soon GBBO <allcaps> too soon. <repeat> <hashtag> neverforget'
#  'CLIMATE CONSEQUENCES: U.S. <allcaps> Forest Service Says Spending More Than Half Of Budget On Fires <url> <url>'
#  'I WAS PEACEFULLY SITTING IN MY ROOM AND I HEARD THIS LOUD BANG OF SOMETHING <allcaps> FALLING'
#  ' <user>  <user>  <user> Thank you  <user> and  <user> for helping so many people in need all over the world. <repeat> <url> \x89Û_'
#  '<hashtag> Metepec <hashtag> Mexico - ?NIGHT DISASTER. <allcaps> <repeat>E(Oficial) @ <hashtag> NitClub <hashtag> mÌ¼sica <hashtag> mÌ¼sica <url>'
#  'Ancient Mayan Tablet with Hieroglyphics Honors Lowly King: A <number>-year-old Mayan stone tablet describing the . <repeat> <url>'
#  'It may seem like our fire has been a little burnt out. <repeat>'
#  " <user>  <user> Oh okay I just got the message twice and got suspicious. Sorry.  I'll check it out!"
#  'Dublin I<number> E / <allcaps> I<number> E North Flynn Rd Onr Trfc Collision-No Inj <url>'
#  'Civilian casualties rise as Afghan war intensifies in <number>-- <url>'
#  'Conning Builds Strong Case for Portfolio <hashtag> Diversification for Property-Casualty Insurers <url>'
#  '-=<number>. <repeat> Photo: LASTMA <allcaps> officials challenge police for driving against traffic in Lagos <url>'
#  '<url> \nSeems they declared war against government. <repeat>'
#  'Governor allows parole for California school bus hijacker <url> <hashtag> fresno'
#  ' <user>  <user> When you call to report dangerous activity tell em to have body bags on arrival.'
#  'Obama Declares Disaster for Typhoon-Devastated Saipan: Obama signs disaster declaration for Northern Marians a. <repeat> <url>'
#  'Just absolutely obliterated a moth my new purchase is boss'
#  'Cramer: Iger\x89Ûªs <number> words that wrecked Disney\x89Ûªs stock \x89ÛÒåÊCNBC <url>'
#  'that horrible sinking feeling when you\x89Ûªve been at home on your phone for a while and you realise its been on <number>G this whole time'
#  "The Storm Prediction Center has expanded the 'Slight Risk' area to include more of central NC. <allcaps> <hashtag> TWCNews <hashtag> ncwx <url>"
#  " <user> Welcome - Read a free chapter of my new book Encounters With Jesus. It's full of hope. <url>"
#  ' <user> Thx for emergency dec. <url> <number> days and no plan to get H<number> to those who have no transport. Can you deploy troops?'
#  'Kids got Disney version of the game Operation only <number> AA <allcaps> batteries? I swear my old version had like <number> Ds and would nearly electrocute you.'
#  "Anyone else getting tons of telemarketing calls on their cell phone? I've been deluged!"
#  "I love the song 'healing is here-deluge' wanted to sing it at my church but it's not in spanish so I translated it. <url>"
#  'Schools in Western Uganda still Burning down Buildings during Strikes. <repeat>Strikes in Western Uganda always Lit literally. <repeat>'
#  "Once again black men didn't make it that way. White men did so why are black men getting attacked  <url>"
#  'Rather violent storm. Possibility of no stream tonight.'
#  'INFO S. <allcaps> WN<smile> <number>/<number> CL<smile> SCT<number> BKN<number> EXP INST APCH. RWY <allcaps> <number> CURFEW IN OPER UNTIL <allcaps> <number> Z. TAXIWAYS FOXTROT <allcaps> <number>  FOXTROT <allcaps> <number> NAVBL. TMP: <allcaps> <number>'
#  'This guy idk just made me his woman crush ? <repeat> first one ever ? <repeat>'
#  'The summer program I worked for went the city pool we had to evacuate because one of my kids left a surprise.  <user> <hashtag> WorstSummerJob'
#  "Ever since my Facebook <hashtag> Mets meltdown after the Padres fiasco- mets are <number><number> You're welcome"
#  'I will never support looting or the burning of buildings but when seeing the people fight back against the police. I was proud'
#  'After a violent afternoon storm more severe weather heads for Chicago tonight. Details ---- <allcaps> <url>'
#  ' <user> listen to hurricane'
#  'The United Kingdom and France are bombing Daesh in Syria - Voltaire Network <url>'
#  " <user> on northgate by the taco truck that's fire."
#  'In memory of the victims of Hiroshima and Nagasaki. Never again! Ban nuclear weapons! : <url>'
#  'California wildfire destroys more homes but crews advance <url> Free tool online <url>'
#  'I gained <number> followers in the last week. You? Know your stats and grow with <url>'
#  "'I can't have kids cuz I got in a bicycle accident  split my testicles. it's impossible for me to have kids' MICHAEL YOU ARE THE <allcaps> FATHER"
#  'THIS SOUNDS LIKE A SONG YOU WOULD HEAR IN A MOVIE WHERE THEY ARE WALKING AWAY FROM BURNING BUILDINGS AND CARS AND <allcaps> SHIT'
#  "I'm glad when I call someone it's not an emergency since they never answer their phones or call back? <repeat>"
#  'Officer Wounded Suspect Killed in Exchange of Gunfire: Richmond police officer wounded suspect killed in exc. <repeat> <url>'
#  'When love and hate collided part II\nLanjut dirumah. <repeat>\n\n<hashtag> yagitudeh - Jake (at Rumah Cipinang) \x89ÛÓ <url>'
#  " <user> I couldn't. <hashtag> mudslide"
#  "'i never understood guys who wanted to run into burning buildings.'\n'you chase murderers.'\n'not if they're on fire.'"
#  ' <user> Also pls help us w/ our campaign to warn the public about the hazardous keratin treatments. The Brazilian Blowout COPYCATS.'
#  '<hashtag> OVOFest Drake straight body bagging Meek on that OVO <allcaps> stage. <hashtag> ZIPHIMUP!'
#  ' <user> FATALITY! <allcaps> <repeat>' 'Flattened thee striker'
#  '<hashtag> Russian food crematoria provokes outrage amid crisis famine memories <url>'
#  'Jetstar and Virgin forced to cancel Bali flights again because of ash from Mount Raung volcano <url>'
#  "the road to success is paved with pennies that I flattened on the train tracks you're welcome."
#  'George Njenga the hero saved his burning friend from a razing wildfire <url>'
#  'Downtown Emergency Service Center is hiring a <hashtag> Chemical <hashtag> Dependency Counselor or Intern apply now! <hashtag> Seattle <hashtag> jobs <url>'
#  " <user> besides your nasty thunderstorm or snowstorm nah. Can't say that I have."
#  'Christian Attacked by Muslims at the Temple Mount after Waving Israeli Flag via Pamela Geller - . <allcaps> <repeat> <url>'
#  'May Allah help all those suffering from the <hashtag> Pakistan floods! You and your families are in our <hashtag> Dua'
#  'HURRICANE GUILLERMO LIVE NOAA TRACKING / LOOPING <allcaps> WED.AUG<number>TH ~ <url> ~  <url> <url>'
#  ' <user> åÇ and probably even more. But some disagreements with General Ross and the catastrophic occurrence made something clear. åÈ'
#  'Evacuation Advisory for Swayback Ridge Area. <repeat>voluntary-InciWeb:Mad River Complex Announcement <url> <hashtag> wildfires <hashtag> calfires'
#  "RT to ruin  <user> 's day.  <url>"
#  'Critters climate and two plague deaths in Colorado <url>'
#  " <user> Do we all use the same weapon? 'cause we might be screwed XD"
#  'Tell the United Nations: Plantations are NOT <allcaps> forests! <url> via  <user>'
#  ' <user>  <user> O-line and pass rush.  Rest of roster is stout barring injuries'
#  "Gonna call up tomorrow with the aul 'emergency dental appointment' excuse just like the whole tooth falling out incident of last year"
#  'To ouvindo sleeping with sirens awn'
#  '<url> Twelve feared killed in Pakistani air ambulance helicopter crash <url>'
#  ' <user> We need help! Horses will die!Please RT  <allcaps> sign petition!Take a stand  be a voice for them! <hashtag> gilbert<number> <url>'
#  ' <user>  <user> Sweet Lord.  (I <allcaps> collapse as my knees buckle)'
#  'Warfighting Robots Could Reduce Civilian Casualties So Calling for a. <repeat> <url>'
#  'CTD arrest three vital criminals from Orangi: KARACHI: <allcaps> Counter-Terrorism Department (CTD) <allcaps> of the Sindh Police . <repeat> <url>'
#  "Don't let the <hashtag> tubestrike derail your mood and join us at the Pisco Bar for drinks after work!  <hashtag> coya <hashtag> london <url>"
#  ' <user>  <user> and I wrecked you both'
#  " <user> ? <repeat> I'm sorry. But I'm out"
#  ' <user> then have the biggest nuclear disaster to ever have happened'
#  'This Friday! <repeat> Club Vault <number>rd Floor EpiCentre <url>'
#  'Doves - The Storm + Greatest Denier (Electric Proms Pt<number>) <url>'
#  'Fr cuz I risk being electrocuted every shower ? <repeat> <url>'
# ...
#  "Reddit's new content policy shows that maybe Reddit can't have it all <url> via  <user> <url>"
#  '<number> new fashion ladies gold watch waterproof WeiQin famous brand michel quartz de lujo ca\x89Û_ <url> <url>'
#  "Diageo's CEO <allcaps> stresses that a board revolt at United Spirits has not impacted Indian operations <url>"
#  '<number>yr old PKK <allcaps> suicide bomber who detonated bomb in Turkey Army trench released <url>'
#  'Photoshop Tools Crash Course - Complete Photoshop Tool Guide <url> <hashtag> course <url>'
#  'Wake Up Kern County Eyewitness News Mornings airing RIGHT NOW <allcaps> on KBAK <allcaps> CBS<number> <url> <hashtag> liveonKBAK <url>'
#  'Longest Streak of Triple-Digit Heat Since <number> Forecast in Dallas: An unrelenting and dangerous heat wave will. <repeat> <url>'
#  '<hashtag>  handbags Genuine Mulberry Antony Cross Body Messenger Bag Dark Oak Soft Buffalo Leather:  å£<number>End Date: W. <allcaps> <repeat> <url>'
#  "What's wrong with just a lil smoke and good conversation ? <repeat>"
#  'Acc to the study conducted by SKIMS <allcaps> morethan <number>% population in <hashtag> Kashmir suffer psychiatric disorders <url> <hashtag> KashmirConflict'
#  'Honestly nightmarish. God driving to new places is always stressful as shit  i hate it so much. Ugh. Almost crashed a few times'
#  'michael is engulfed by that jumper'
#  "Wreckage 'Conclusively Confirmed' as From MH<number> Malaysia PM: <allcaps> Investigators and the families of those who were. <repeat> <url>"
#  'Remove the <url> and Linkury Browser Hijacker <url> <url>'
#  'Vince McMahon once again a billionaire: I remember reading a deluge of posts about Vince McMahon losing $<number> m. <repeat> <url>'
#  'My ears are bleeding  <url>'
#  'burned <number> calories doing <number> minutes of Walking <number> mph brisk pace <hashtag> myfitnesspal'
#  ' <user> really needs to tone it down some in the weight room. RT  <allcaps> <user> Demolition (cont) <url>'
#  'There have been zero spider bite-related fatalities in Australia since <number>'
#  'If you are quiet enough you can literally hear the phandom screaming at the tyler tweet'
#  '<hashtag> Bestnaijamade: <number>yr old PKK <allcaps> suicide bomber who detonated bomb in . <repeat> <url> bestnaijamade bestnaijamade bestnaijamade be\x89Û_'
#  'White Twister Black shift knob M<number>x<number> Thread Size <url> <url>'
#  'Plains: Calif. Oil Spill Could be Larger than Estimated. <url>'
#  'Do you know the emergency plan at your workplace? If not ask your supervisor or operations manager. <hashtag> Retail'
#  'the war on drugs has turned the U.S. <allcaps> into a WAR <allcaps> zone.'
#  " <user> It is indeed. If the apocalypse comes this week I know where I'll be <smile>"
#  'Kosciusko police investigating pedestrian fatality hit by a train Thursday <url>'
#  'eggs desolate'
#  " <user> he's alright but Hazard/Willian ain't gonna be shifted easily."
#  'Twitter is just here to destroy your childhood'
#  ". <repeat>don't think I've ever been this close to a mental explosion in so long"
#  'Learn How I Gained Access To The Secrets Of The Top Earners  Used Them To Explode My Home Business Here: <url> Please <hashtag> RT'
#  '<hashtag> foodscare <hashtag> offers<number>go <hashtag> NestleIndia slips into loss after <hashtag> Magginoodle <hashtag> ban unsafe and hazardous for <hashtag> humanconsumption'
#  'Truth. <repeat>\n<url>\n<hashtag> News\n<hashtag> BBC\n<hashtag> CNN\n<hashtag> Islam\n<hashtag> Truth\n<hashtag> god\n<hashtag> ISIS\n<hashtag> terrorism\n<hashtag> Quran\n<hashtag> Lies <url>'
#  'Heat wave is ending! Watching a big area of rain though. <repeat>will impact part of the area. Details NOW <allcaps> on NBC<number> at <number>pm'
#  'Tips to prevent basement leaks - Create control joints to eliminate random cracking. <hashtag> homeimprovement <hashtag> Flooding <url>'
#  'Kurd Suicide Attack Kills <number> Turkish Soldiers <url>'
#  " <user> let's try to do our best to prevent another outbreak of violence by talking to each other both the people and the politics"
#  'I smoke to <elong> much lmao I was scared to text this number bck but now it all makes sense lol'
#  'New Nanotech Device Will Be Able To Target And Destroy Blood Clots <url>'
#  '\x89ÛÏ <user> ? <repeat> No Caption Needed . <repeat> Freshman. <repeat> <url> nigga Stacey body bagging niggas! ? <repeat>'
#  "Tonight It's Going To Be Mayhem @ <hashtag> <number>PlayThursdays. Everybody Free w/ Text. <number> I ST NW <allcaps> (<number>+) <url>"
#  'FOOTBALL IS BACK THIS WEEKEND ITS JUST SUNK IN ? <allcaps> <repeat>'
#  'The once desolate valley was transformed into a thriving hub of hi\x89ÛÓtech business.'
#  'INVESTMENT NEWS <allcaps> Keurig Green Mountain Inc. Third-Quarter Earnings: Shares Sinking After-Hours - Stocks in the New\x89Û_ <url>'
#  '<hashtag> stlouis <hashtag> caraccidentlawyer Speeding Among Top Causes of Teen Accidents <url> <url> Car Accident tee\x89Û_'
#  "Ercjmnea: Breaking news! Unconfirmed! I just heard a loud bang nearby. in what appears to be a blast of wind from my neighbour's ass."
#  'Get a load of this welfare loving sponge. <repeat>a blight on society. <url>'
#  'My head gonna explode soon'
#  'A Tale of Two Pox - Body Horrors <url> <hashtag> virus <hashtag> infectiousdiseases <hashtag> bioterrorism'
#  'KATUNews: <hashtag> SR<number> remains closed as brush fire burns <number> acres: <url> <hashtag> LiveOnK<number> <url>'
#  "I'm about to explode ? <repeat>"
#  "USATODAY: On today's <hashtag> frontpage: <hashtag> Bioterror lab faced secret sanctions. <hashtag> RickPerry doesn't make the cut for FoxNew\x89Û_ <url>"
#  ' <user> Rescuers are searching for hundreds of migrants in the Mediterranean after a boat carr. <repeat> <url>  <user>'
#  '<number> dead as Afghanistan aircraft crashes: An Afghan military helicopter has crashed in a remote region of the s. <repeat>  <url>'
#  'Rainstorm Destroys <number> Houses in Yobe State: Rainstorm Destroys <number> Houses in Yobe State. [Daily Trust] Damatu. <repeat>  <url>'
#  'Islamic State group in Egypt threatens to kill Croat hostage <url>'
#  'In <hashtag> islam saving a person is equal in reward to saving all humans! Islam is the opposite of terrorism!'
#  'Ted Cruz fires back at Jeb  Bush: \x89ÛÏWe lose because of Republicans like Jeb  Mitt.\x89Û\x9d [Video] -  <allcaps> <url>'
#  "RT: janenelson<number> RT <allcaps> StephenSCIFI: Adaptation Watch: Charlie Human's APOCALYPSE NOW NOW <allcaps> Optioned for Film <hashtag> sciencefiction \x89Û_"
#  'Last Second OutBid RT? <allcaps> <url> <number>pcs <number>mm Ab Resin Flower Whirlwind Flatback Rhinestone Wedding Decoration ?Please Fa'
#  'Washington Post - <number> dead dozens injured in Gaza blast near house leveled in summer war <url>'
#  'Panic at the disco te amo' 'Earthquake drill ? <repeat>'
#  ' <user> Middle of winter in Sydney we have had snow bush fires and <number> degree days in the last week.  Keeps you on your toes for sure.'
#  'New post from  <user> <number> Major Challenges of Channel Sales Enablement <url>'
#  'Dear  <user> I brought it <smile> <hashtag> CanonBringIt <hashtag> Fire  <hashtag> CanonTattoo <hashtag> MN <allcaps> <hashtag> TheresMoreWhereThatCameFrom <url>'
#  "It's crazy how a phone can do so much damage to a person"
#  'This is Lara she likes sinking her teeth into my flesh and clawing my arms ? <repeat> <url>'
#  'What really happened in the Taken King Story Trailer. A space battle that ripped a hole in Saturn.  <user>  <user> <url>'
#  'Choking Hazard Prompts Recall Of Kraft Cheese Singles <url>'
#  'Casualty Team: Ice Cream Recall Sends Chill Through Food Industry <url>'
#  'Learning from the Legacy of a Catastrophic Eruption <url> via  <user>'
#  'LARGE SHIP WRECK FISH TANK ORNAMENT FOR SALE LARGE SHIP WRECK FISH TANK AQUA. <allcaps> <repeat><url>'
#  ' <user> TRUMP IS A CLIMATE DENIER- <allcaps> algae bloom in the pacific from calif to alska- seeweed in caribean forest fires- SNOWBALL <allcaps> INHOFE'
#  "White family (supposedly representing America's GREAT <allcaps> values ) gets blown up in a horrible CGI <allcaps> nuclear strike. <repeat> LMFAO <allcaps> <elong>! <repeat>"
#  'Wondering if gold could gap up $<number> on the jobs numbers tomorrow and just obliterate the shorts. A big player with guys could smash them'
#  'Any new games coming soon  <user> ?'
#  "Ever since Kelly's burned I keep having dreams about being inside burning buildings ? <repeat>"
#  'GREAT MICHIGAN TECHNIQUE <allcaps> CAMP\nB<number>G THANKS TO  <allcaps> <user> \n <user> .  <allcaps> <user> \n<hashtag> GoBlue <hashtag> WrestleOn <url>'
#  "Wreckage 'Conclusively Confirmed' as From MH<number> Malaysia PM: <allcaps> Investigators and the families of those who were. <repeat> <url>"
#  '<hashtag> Landslide! Trump <number>% Bush <number>% <url> via  <user>  <user>'
#  'World Annihilation vs Self Transformation <url> Aliens Attack to Exterminate Humans <url>'
#  'Gunshot wound <hashtag> <number> is in the bicep. The only one of the ten wounds that is not in the chest/torso area.  <hashtag> KerrickTrial <hashtag> JonathanFerrell'
#  " <user> But the design decision to 'Let's make something fresh and beautiful and wonderful and then WRECK IT' <allcaps> is kindof odd in restrospect"
#  "<hashtag> news Politifiact: Harry Reid's '<number> Percent of Women Served' Planned Parenthood Claim Is a 'Pants on Fire' Lie. <repeat> <url>"
#  "Afghanistan: U.N. <allcaps> Reports 'Record-High Levels' of Civilian Casualties\n    <allcaps> \nIn news from Afghanistan the United. <repeat> <url>"
#  ' <user> <hashtag> AskConnor if you were a natural disaster what would you be?'
#  'Rly tragedy in MP: <allcaps> Some live to recount horror: \x89ÛÏWhen I saw coaches of my train plunging into water I called my daughters and said t. <repeat>'
#  'Siren Test complete :: <allcaps> The test has concluded'
#  'Three-alarm fire destroys two residential buildings a car in Manchester N.H. <allcaps> on Sunday afternoon <url>'
#  'Trafford Centre film fans angry after Odeon cinema evacuated following false fire alarm: \n Twitter users tell . <repeat> <url>'
#  'SANTA CRUZ <allcaps> \x89ÛÓ Head of the St Elizabeth Police Superintendent Lanford Salmon has r . <repeat> - <url> <url>'
#  ' <user> not that all abortions get you traumatised. At times you are okay with the decision due to reasons like rape'
#  " <user> Jack closed the sketchbook biting his lip under his mask. 'I'm doing good. How're you?'"
#  'Busty blonde teen Natalia Starr fucks the security guard on set <url> View and download video'
#  'CANADA BC DROUGHT: <allcaps> Okanagan region issued Level <number> rating - Okanagan River (Columbia trib) fishing suspended to Sep <number> <url>'
#  'Mental/Twitter Note: Make sure my smoke alarm battery is up to snuff at all times or face many twitter reminders of changing my battery.'
#  "'California: Spring Oil Spill Estimate Grows ' by THE ASSOCIATED PRESS <allcaps> via NYT <allcaps> <url>"
#  ' <user> we enjoyed the show today. Great fun. The emergency non evacuation was interesting. Have a great run.'
#  " Bin Laden family plane crashed after 'avoiding microlight and landing too far down runway. <repeat> <url> <hashtag> rochdale <hashtag> heywood"
#  'The thunder shook my house woke my sister and made car alarms go off ? <repeat>'
#  " <user> It's the closest structure to the hypo centre that wasn't completely obliterated."
#  'Survivors remorse is good' "The twins pitcher's ego is now WRECKED"
#  'Just had my first counter on a league game against another Orianna I happened to demolish her xD. I totally appreciate people that play her'
#  " <user> I'm telling your mom your up past curfew oth"
#  'Explosion in Gaza Strip kills four wounds <number>; cause unknown <url> via  <user>'
#  'Am I hearing thunder or trucks?'
#  'Severe hailstorm in progress over Northeast Logan County. <repeat> <hashtag> cowx <url>'
#  'But the sea would. <repeat>electrocute us all.'
#  'Yay I can feel the wind gearing up for a rainstorm in <hashtag> Vancouver! <repeat> Bring it on <hashtag> drought <hashtag> deadgrassandflowers <hashtag> wildfires'
#  'Hail The New Caesars! <url> <url>'
#  "Notley's tactful yet very direct response to Harper's attack on Alberta's gov't. Hell YEAH <allcaps> Premier! <url> <hashtag> ableg <hashtag> cdnpoli"
#  "What Irony Debris of Flight MH<number> found on 'Reunion Island'."
#  " <user> 'Don't bother while you were offline I managed to evacuate everyone out of here including Hinata so so go ahead and cause--"
#  'Why did God order obliteration of ancient Canaanites? <url>'
#  "When you're <number> hours late for curfew and have to pray your dog doesn't bark when unlocking the door"
#  'Fear Factory - Cars (Official MusicVideo) <url>'
#  'Business at the Sponge Docks washed out by rain flooding: <url>'
#  "<hashtag> Cowboys: Wednesday's injury report: RB <allcaps> Lance Dunbar injures ankle is listed as day-to-day:  <url>"
#  '<hashtag> spark <hashtag> song Ultimate <hashtag> preparedness library: <url> Prepare Yourself For Any Catastrophe. Over <url>'
#  'Save the upset and stress of upheaval and let us help keep <hashtag> elderly people independent! <hashtag> companionship <hashtag> care <hashtag> Chester  <user>'
#  '<hashtag> CDCwhistleblower <number> deaths from measles complications in <number> yrs everyone looses their shit. <number> dead from Legionnaires in a month  crickets'
#  '<number> former executives to be prosecuted in Fukushima nuclear disaster <url>'
#  ' <user> if you loved me even a little youd put demolition in bo<number>'
#  "For these Californians it's like living in Africa's Sahel desert - just finding water a daily chore. <url>"
#  'the bar method \x89ÛÓ integrates the fat burning format of interval training the muscle shaping techniqu <url>'
#  "I attacked Robot-lvl <number> and I've earned a total of <number> free satoshis! <url> <hashtag> robotcoingame <hashtag> Bitcoin <hashtag> FreeBitcoin"
#  ' <user> haha so would you say its so hot your balls are burning off? <repeat>'
#  "Apparently my face screams \n'Get me emotionally attached and then cheat on me'"
#  'I liked a  <user> video from  <user> <url> GUN RANGE <allcaps> MAYHEM!'
#  'Severe Thunderstorms and Flash Flooding Possible in the Mid-South and Midwest <url> <hashtag> WEATHER <allcaps> <hashtag> ENVIRONMENT <allcaps> <hashtag> CLIMATE <allcaps> <hashtag> NATURE'
#  "I would like to electrocute everyone who uses the word 'fair' in connection with income tax policies. - William F. <allcaps> Buckley Jr."
#  'If Schwarber ran into me going that fast I would explode into pieces'
#  'Pandemonium In Aba As Woman Delivers Baby Without Face (Photos) <url> <url>'
#  "Came across this fire video not mine. <repeat>enjoy. <repeat>Babes way of saying hi to me while he's in the fire truck? <repeat>\n<hashtag> fireman <hashtag> \x89Û_ <url>"
#  'Alabama home quarantined over possible Ebola case: Officials say a quarantine is in place at . <repeat> <url> <hashtag> Bluehand <hashtag> PJNET'
#  '<hashtag> Glimpses: Hyderabad deluged by heavy rainfall | <url> <url>'
#  "Yup. Still hasn't sunk in. ? <repeat> <url>"
#  'Vassalboro house to be razed to make way for public gazebo  <user> reports. <url>'
#  'Imagini noi si <number> clipuri The Hobbit: The Desolation of Smaug -. <allcaps> <repeat> <url> <hashtag> cliptv <hashtag> desolationofsmaug <hashtag> poze <hashtag> thehobbit'
#  "Grow Calgary avoids worst of city's wicked weather  ~ <number> <url> <url>"
#  ' <user> there were plenty of black people rioting when tOSU won the championship as well.'
#  "You call them weekends. I call them Bloody Mary times. This summer's been full of them. My new\x89Û_ <url>"
#  'Four Things That May Ruin Your Personal Injury Accident Claim <url>'
#  'Israel continues its demolition of Palestinian homes <hashtag> gop <hashtag> potus <hashtag> irandeal <hashtag> isis  <url>'
#  ' <user> leos ass just got metaphorically blown up again <hashtag> PiperWearsThePants <hashtag> charmed'
#  'Mourning notices for stabbing arson victims stir \x89Û÷politics of grief\x89Ûª in Israel <url>'
#  'Bad day'
#  'A deluge of eulogies  for <hashtag> CecilTheLion on my WhatsApp  this too tormented soul by matias xavier ']

# %% [markdown]
# ### Create functions used to create submission to Kaggle

# %%
def CreateVectorizerSumbission(clf, vectorizer):
    xtrain_full_v = vectorizer.transform(xtrain_full)
    
    clf.fit(xtrain_full_v, ytrain_full)
    test_acc = metrics.f1_score(clf.predict(xtrain_full_v), ytrain_full)

    xtest_full_v = vectorizer.transform(xtest_full)
    predictions = clf.predict(xtest_full_v)
    output = pd.DataFrame({'id': test_df.id, 'target': predictions})
    output.to_csv('my_submission.csv', index=False)
    
    return test_acc

# %% [markdown]
# # 2. Word Processor
# This will take all our examples and build a model to be used to train on.

# %%
# This will display what is contained in the CountVectorizer or TFIDF output at the given index
def DisplayWordVectorValues(vectorizer, vectors, index):
    df = pd.DataFrame()
    cx = vectors[index].tocoo()
    start=1
    for i,j,v in zip(cx.row, cx.col, cx.data):
        if start==1:
            df = pd.DataFrame({'Type': ['Index','Count'], vectorizer.get_feature_names()[j]: [j,v]})
            start=0
        else:
            d = pd.DataFrame({'Type': ['Index','Count'], vectorizer.get_feature_names()[j]: [j,v]})
            df = df.merge(d,left_on=['Type'], right_on=['Type'])
    return df

# %% [markdown]
# ### CountVectorizer

# %%
from sklearn import feature_extraction

ctv = feature_extraction.text.CountVectorizer(analyzer='word',token_pattern=r'\w{1,}',
            ngram_range=(1, 3))

ctv.fit(list(xtrain) + list(xvalid))
#train_vectors = ctv.fit_transform(xtrain)
xtrain_ctv = ctv.transform(xtrain)
xvalid_ctv = ctv.transform(xvalid)
xtrain_ctv_full = ctv.transform(xtrain_full)

print('Example of what the data we\'re going to train on looks like:')
ex = 75 #42 75
print(f'--------------------------------------------------\nIn: {xtrain[ex]}\n--------------------------------------------------\nOut:')
print(DisplayWordVectorValues(ctv, xtrain_ctv, ex))
# Out:
# Example of what the data we're going to train on looks like:
# --------------------------------------------------
# In: <hashtag> Lifestyle Û÷It makes me sickÛª: Baby clothes deemed a Û÷hazardÛª <url> <url>
# --------------------------------------------------
# Out:
#     Type   a   a û  a û hazard   baby  baby clothes  baby clothes deemed  \
# 0  Index  17  2505        2506  15239         15245                15246
# 1  Count   1     1           1      1             1                    1
#
#    clothes  clothes deemed  clothes deemed a  deemed  deemed a  deemed a û  \
# 0    28188           28191             28192   33968     33969       33970
# 1        1               1                 1       1         1           1
#
#    hashtag  hashtag lifestyle  hashtag lifestyle û  hazard  hazard ûª  \
# 0    55025              56900                56901   59484      59541
# 1        1                  1                    1       1          1
#
#    hazard ûª url     it  it makes  it makes me  lifestyle  lifestyle û  \
# 0          59542  71574     71888        71889      77419        77422
# 1              1      1         1            1          1            1
#
#    lifestyle û it  makes  makes me  makes me sick     me  me sick  me sick ûª  \
# 0           77423  81087     81090          81095  82551    82822       82823
# 1               1      1         1              1      1        1           1
#
#      sick  sick ûª  sick ûª baby     url  url url       û  û hazard  \
# 0  119217   119236        119237  144038   144673  159727    159778
# 1       1        1             1       2        1       2         1
#
#    û hazard ûª    û it  û it makes      ûª  ûª baby  ûª baby clothes  ûª url  \
# 0       159779  159796      159798  159915   159924           159925  159966
# 1            1       1           1       2        1                1       1
#
#    ûª url url
# 0      159968
# 1           1

# %% [markdown]
# ### TFIDF - Term Frequency - Inverse Document Frequency

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfv = TfidfVectorizer(min_df=3,  max_features=None, 
            strip_accents='unicode', analyzer='word',token_pattern=r'\w{1,}',
            ngram_range=(1, 3), use_idf=1,smooth_idf=1,sublinear_tf=1,
            stop_words = 'english')

tfv.fit(list(xtrain) + list(xvalid))
xtrain_tfv =  tfv.transform(xtrain) 
xvalid_tfv = tfv.transform(xvalid)
xtrain_tfv_full = tfv.transform(xtrain_full)


print('Example of what the data we\'re going to train on looks like:')
ex = 42 #42 75
print(f'--------------------------------------------------\nIn: {xtrain[ex]}\n--------------------------------------------------\nOut:')
print(DisplayWordVectorValues(tfv, xtrain_tfv, ex))
# Out:
# Example of what the data we're going to train on looks like:
# --------------------------------------------------
# In: Lose bus card.
# Panic.
# Kind bus driver.
# Replace bus card.
# Find bus card.
# Headdesk.
# --------------------------------------------------
# Out:
#     Type      replace        panic         lose         kind       driver  \
# 0  Index  7240.000000  6440.000000  5101.000000  4695.000000  2389.000000
# 1  Count     0.270794     0.217746     0.263774     0.291357     0.248545
#
#           card          bus
# 0  1294.000000  1165.000000
# 1     0.611446     0.537728

# %% [markdown]
# # 3. Experiment with Solo Algorithms
# Here I'm going to try several different models to see what works best against the validation set.

# %% [markdown]
# ## 3.1 RidgeClassifier
# This is just linear regression with a regularization parameter

# %%
# This will do 3 sets of cross-validation.  Since we've already done cross-validation above, we use the standard fit/predict method
# from sklearn import model_selection
# clf = linear_model.RidgeClassifier()
# scores = model_selection.cross_val_score(clf, train_vectors, ytrain, cv=3, scoring="f1")
# scores
#  Result: [0.70359281, 0.71489971, 0.73281361]

# %%
from sklearn import linear_model
from sklearn import metrics

clf = linear_model.RidgeClassifier()

clf.fit(xtrain_ctv, ytrain)
print(f'CountVector Result:\t{metrics.f1_score(clf.predict(xvalid_ctv), yvalid)}')  # Result: 0.7362581946545639
clf.fit(xtrain_tfv, ytrain)
print(f'TFIDF Result:\t\t{metrics.f1_score(clf.predict(xvalid_tfv), yvalid)}')  # Result: 0.7541463414634147
# Out:
# CountVector Result:	0.7332998493219488
# TFIDF Result:		0.7478091528724441

# %% [markdown]
# ## 3.2 Linear Regression

# %%
from sklearn import linear_model
from sklearn import metrics

clf = linear_model.LogisticRegression(C=1.0, max_iter=500)

clf.fit(xtrain_ctv, ytrain)
print(f'CountVector Result:\t{metrics.f1_score(clf.predict(xvalid_ctv), yvalid)}')  # Result: 0.7486201705970899
clf.fit(xtrain_tfv, ytrain)
print(f'TFIDF Result:\t\t{metrics.f1_score(clf.predict(xvalid_tfv), yvalid)}')  # Result: 0.7580893682588599
# Out:
# CountVector Result:	0.7475149105367793
# TFIDF Result:		0.7539480387162506

# %%
#print(CreateVectorizerSumbission(clf, tfv))

#0.8346430362815581 / 0.79711 (no http)
#0.8372015361496077 / 0.79619 (with http)

# %% [markdown]
# ## 3.3 Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

clf = MultinomialNB()

clf.fit(xtrain_ctv, ytrain)
print(f'CountVector Result:\t{metrics.f1_score(clf.predict(xvalid_ctv), yvalid)}')  # Result: 0.7607807535179302
clf.fit(xtrain_tfv, ytrain)
print(f'TFIDF Result:\t\t{metrics.f1_score(clf.predict(xvalid_tfv), yvalid)}')  # Result: 0.7420382165605096
# Out:
# CountVector Result:	0.7488500459981601
# TFIDF Result:		0.7324396782841823

# %%
#print(CreateVectorizerSumbission(clf, ctv)) 

#0.9693972179289025 / 0.80110 (no http)
#0.9697156983930779 / 0.80202 (no http, numbers or &;)

# %% [markdown]
# ## 3.4 SVM
# TruncatedSVD - Singular Value Decomposition will be used to reduce the parameter set and standardize the data

# %%
# from sklearn.decomposition import TruncatedSVD
# from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn import metrics

# # Reduce parameters --> no benefit in score
# svd = TruncatedSVD(n_components=120)
# svd.fit(xtrain_tfv)
# xtrain_svd = svd.transform(xtrain_tfv)
# xvalid_svd = svd.transform(xvalid_tfv)

# # Scaled...
# scl = StandardScaler()
# scl.fit(xtrain_svd)
# xtrain_svd_scl = scl.transform(xtrain_svd)
# xvalid_svd_scl = scl.transform(xvalid_svd)

clf = SVC(C=1.0, probability=True) 

clf.fit(xtrain_tfv, ytrain)
print(f'TFIDF Result:\t\t{metrics.f1_score(clf.predict(xvalid_tfv), yvalid)}')  # Result: 0.7424400417101147
# Out:
# TFIDF Result:		0.7348008385744234

# %% [markdown]
# ## 3.5 XGBoost

# %%
import xgboost as xgb
from sklearn import metrics

clf = xgb.XGBClassifier(max_depth=6, n_estimators=500, colsample_bytree=0.8, 
                        subsample=0.8, nthread=10, learning_rate=0.1)

clf.fit(xtrain_ctv, ytrain)
print(f'CountVector Result:\t{metrics.f1_score(clf.predict(xvalid_ctv), yvalid)}')  # Result: 0.7524461839530333
clf.fit(xtrain_tfv, ytrain)
print(f'TFIDF Result:\t\t{metrics.f1_score(clf.predict(xvalid_tfv), yvalid)}')  # Result: 0.735678391959799
# Out:
# CountVector Result:	0.7513434294088911
# TFIDF Result:		0.7433102081268582

# %% [markdown]
# # 4. GridSearch and Pipeline

# %%
from sklearn.metrics import f1_score, make_scorer
f1_scorer = make_scorer(f1_score)

def GetBestScoreString(clf, param_grid):
    output = ""
    best = clf.best_estimator_.get_params()
    for p in sorted(param_grid.keys()):
        output += "%s: %r " % (p, best[p])
    return output

# %% [markdown]
# ## 4.1 Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import pipeline
from sklearn.model_selection import GridSearchCV

nb_model = MultinomialNB()
pline = pipeline.Pipeline([('nb', nb_model)])

param_grid = {'nb__alpha': [0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6, 10]}
clf = GridSearchCV(estimator=pline, param_grid=param_grid, scoring=f1_scorer,
                     verbose=10, n_jobs=-1, iid=True, cv=2)

clf.fit(xtrain_ctv, ytrain)
print(f'CountVector Result:\t{clf.best_score_} [Params = {GetBestScoreString(clf, param_grid)}]')  # Result: 0.7607807535179302
clf.fit(xtrain_tfv, ytrain)
print(f'TFIDF Result:\t\t{clf.best_score_} [Params = {GetBestScoreString(clf, param_grid)}]')  # Result: 0.7420382165605096

# %% [markdown]
# # 5. Word Vectors

# %% [markdown]
# ## 5.1 Global Vectors (GloVe)
# Here we're goign to use a pre-trained model that was developed by Stanford on a Twitter dataset.  This model contains vector representations of each word so when comparing two or more words, their dot product equals the logarithm of the words' probability of co-occurrence.
# Source: https://nlp.stanford.edu/projects/glove/

# %%
from tqdm.notebook import tqdm  # This is an awesome library that shows the progress of whatever tqdm() is applied to

with open('D:\Datasets\GloVe\glove.twitter.27B.25d.txt', 'r', encoding="utf8") as f:
    embeddings_index = {}
    for line in tqdm(f):
        vals = line.rstrip().split(' ')
        embeddings_index[vals[0]] = [float(x) for x in vals[1:]]
print('Found %s word vectors.' % len(embeddings_index))  #1193514
# Out:
# 1193514it [00:09, 125899.07it/s]
# Found 1193514 word vectors.

# %%
# Prior to using stanfordnlp, I needed to install pyTorch.
# How to install pyTorch: https://pytorch.org/get-started/locally/#mac-anaconda
#     conda install pytorch torchvision cudatoolkit=10.2 -c pytorch
# Then I could run `pip install stanfordnlp`

# import stanfordnlp
# #stanfordnlp.download("en")  # run this the first time
# nlp = stanfordnlp.Pipeline(processors='tokenize', lang='en')
# doc = nlp(xtrain[0])
# print(*[f'word: {word.text+" "}\tlemma: {word.lemma}' for sent in doc.sentences for word in sent.words], sep='\n')

# %%
# import nltk
# nltk.download('punkt')
# nltk.download('stopwords')

from nltk import word_tokenize
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
import re

def new_tokenize(s):
    # This will regroup key_words like '<', 'hashtag', '>' into '<hashtag>'
    words = word_tokenize(s)
    new_words = []
    skip = 0
    for i, w in enumerate(words):
        if skip > 0:
            skip = skip-1
        else:
            if w == '<' and words[i+1] in key_words and words[i+2] == '>':
                new_words.append('<' + words[i+1] + '>')
                skip = 2
            else:
                new_words.append(w)
    return new_words
            

def sent2vec(s):
    words = str(s).lower()
    words = new_tokenize(words)
    words = [w for w in words if not w in stop_words]
    words = [w for w in words if w.isalpha() or re.match("<\S+>",w)]
    M = []
    for w in words:
        try:
            # This adds the np.array (size=25) of values from the GloVe file for each word to the matrix
            M.append(embeddings_index[w])
        except:
            continue
    M = np.array(M)
    
    # Now we sum up each column to create a vector of size 25
    v = M.sum(axis=0)
    
    if type(v) != np.ndarray:
        return np.zeros(300)
    
    # I don't understand what the heck this is doing...
    return v / np.sqrt((v ** 2).sum())


# Print an example to show what this does...
s = xtrain[1973]
print (s)
print (word_tokenize(s))
print (new_tokenize(s))
print (sent2vec(s))
# Out:
# screams internally
# ['screams', 'internally']
# ['screams', 'internally']
# [-0.18842637 -0.14155117  0.13611215  0.14572803 -0.01665227 -0.16658199
#   0.33013203 -0.39650936 -0.1280619   0.09574502 -0.1280681   0.35729542
#  -0.2917416  -0.07044935 -0.07878197  0.1386751  -0.0919395   0.08689471
#   0.10740657 -0.3965204   0.15054632  0.02527084  0.25635967 -0.14913656
#  -0.17113405]

# %%
# This is me trying to figure out what the above is doing... Still don't get it!

# import re

# s = xtest_full[13]
# words = str(s).lower()
# words = new_tokenize(words)
# words = [w for w in words if not w in stop_words]
# print (words)
# words = [w for w in words if w.isalpha() or re.match("<\S+>",w)]
# print (words)
# M = []
# for w in words:
#     try:
#         M.append(embeddings_index[w])
#     except:
#         continue
# M = np.array(M)
# v = M.sum(axis=0)
# print (words)
# print (M)
# print(v)  # must remember v is a sum of the columns
# print(v**2)
# print((v**2).sum())  # this is a sum on the row
# print(np.sqrt((v**2).sum()))
# print(v /np.sqrt((v**2).sum()))
# print (v / np.std(v))

# %%
from tqdm.notebook import tqdm

xtrain_glove = [sent2vec(x) for x in tqdm(xtrain)]
xvalid_glove = [sent2vec(x) for x in tqdm(xvalid)]
xtrain_full_glove = [sent2vec(x) for x in tqdm(xtrain_full)]
xtest_full_glove = [sent2vec(x) for x in tqdm(xtest_full)]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5077.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2536.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=7613.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=3263.0), HTML(value='')))

# %%
for i, v in enumerate(xtest_full_glove):
    if len(v) > 25:
        print(f'Index = {i}')

# %%
xtrain_glove_np = np.stack(xtrain_glove)
xvalid_glove_np = np.stack(xvalid_glove)
xtrain_full_glove_np = np.stack(xtrain_full_glove)
xtest_full_glove_np = np.stack(xtest_full_glove)

# %% [markdown]
# ### 5.1.1 XGBClassifier

# %%
import xgboost as xgb
from sklearn import metrics

# clf = xgb.XGBClassifier(max_depth=6, n_estimators=180, colsample_bytree=0.8,   # Result: 0.7417794970986459
#                         subsample=0.8, nthread=10, learning_rate=0.1)

# clf = xgb.XGBClassifier(max_depth=5, n_estimators=150, colsample_bytree=0.5,   # Result: 0.7229254571026722
#                         subsample=0.6, nthread=10, learning_rate=0.6)

clf = xgb.XGBClassifier(max_depth=6, n_estimators=150, colsample_bytree=0.6,   # Result: 0.7554691298006806
                        subsample=0.7, nthread=10, learning_rate=0.1)

clf.fit(xtrain_glove_np, ytrain)
print(f'CountVector Result:\t{metrics.f1_score(clf.predict(xvalid_glove_np), yvalid)}')
# Out:
# CountVector Result:	0.7554691298006806

# %% [markdown]
# Using a GridSearch to find Best Parameters.

# %%
# xg_model = xgb.XGBClassifier()
# from sklearn import pipeline
# from sklearn.model_selection import GridSearchCV

# pline = pipeline.Pipeline([('xg', xg_model)])

# param_grid = {'xg__max_depth': [4,5,6],
#               'xg__n_estimators': [150,160,170,180],
#               'xg__colsample_bytree': [0.5,0.6,0.7,0.8],
#               'xg__subsample': [0.6,0.7,0.8],
#               'xg__learning_rate': [0.1,0.3,0.5,0.6]}
# clf = GridSearchCV(estimator=pline, param_grid=param_grid, scoring=f1_scorer,
#                      verbose=10, cv=2)

# clf.fit(xtrain_full_glove_np, ytrain_full)
# print(f'CountVector Result:\t{clf.best_score_} [Params = {GetBestScoreString(clf, param_grid)}]')  # Result: 0.7607807535179302

# Output:
#CountVector Result:	0.7249966532003029 [Params = xg__colsample_bytree: 0.5 xg__learning_rate: 0.06 xg__max_depth: 5 xg__n_estimators: 150 xg__subsample: 0.6 ]

# Output 2:
#CountVector Result:	0.7211488547217996 [Params = xg__colsample_bytree: 0.6 xg__learning_rate: 0.1 xg__max_depth: 6 xg__n_estimators: 150 xg__subsample: 0.7 ]
# Out:
# Fitting 2 folds for each of 576 candidates, totalling 1152 fits
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.6, score=0.713, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.6
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.6, score=0.710, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.7, score=0.708, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.7
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.7, score=0.724, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.8, score=0.714, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.8
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.6s remaining:    0.0s
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.8, score=0.723, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.6, score=0.717, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.6
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.9s remaining:    0.0s
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.6, score=0.711, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.7, score=0.711, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.7
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    1.1s remaining:    0.0s
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.7, score=0.726, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8, score=0.716, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8, score=0.723, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6, score=0.710, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6, score=0.711, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7, score=0.710, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7, score=0.721, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8, score=0.714, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8, score=0.721, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6, score=0.713, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6, score=0.706, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7, score=0.710, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7, score=0.724, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8, score=0.713, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8, score=0.722, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6, score=0.711, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6, score=0.714, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7, score=0.700, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7, score=0.718, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8, score=0.717, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8, score=0.714, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6, score=0.709, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6, score=0.713, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7, score=0.702, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7, score=0.715, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8, score=0.715, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8, score=0.717, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6, score=0.711, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6, score=0.712, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7, score=0.700, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7, score=0.713, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8, score=0.716, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8, score=0.716, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6, score=0.709, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6, score=0.714, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.7, score=0.704, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.7, score=0.715, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.8, score=0.715, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.8, score=0.715, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.6, score=0.717, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.6, score=0.707, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.7, score=0.704, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.7, score=0.722, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.8, score=0.710, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.8, score=0.713, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.6, score=0.717, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.6, score=0.706, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.7, score=0.708, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.7, score=0.719, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.8, score=0.711, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.8, score=0.709, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.6, score=0.717, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.6, score=0.707, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.7, score=0.707, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.7, score=0.718, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.8, score=0.713, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.8, score=0.708, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.6, score=0.717, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.6, score=0.704, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.7, score=0.707, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.7, score=0.717, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.8, score=0.711, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.1, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.8, score=0.708, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.6, score=0.696, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.6, score=0.688, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.7, score=0.698, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.7, score=0.697, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.8, score=0.711, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.8, score=0.703, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.6, score=0.697, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.6, score=0.690, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.7, score=0.697, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.7, score=0.698, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8, score=0.706, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8, score=0.701, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6, score=0.697, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6, score=0.689, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7, score=0.693, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7, score=0.699, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8, score=0.709, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8, score=0.706, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6, score=0.702, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6, score=0.686, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7, score=0.696, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7, score=0.699, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8, score=0.710, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8, score=0.708, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6, score=0.704, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6, score=0.692, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7, score=0.699, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7, score=0.697, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8, score=0.700, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8, score=0.709, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6, score=0.700, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6, score=0.688, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7, score=0.703, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7, score=0.691, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8, score=0.700, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8, score=0.709, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6, score=0.698, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6, score=0.693, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7, score=0.705, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7, score=0.697, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8, score=0.699, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8, score=0.708, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6, score=0.702, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6, score=0.693, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.7, score=0.703, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.7, score=0.701, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.8, score=0.697, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.8, score=0.711, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.6, score=0.698, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.6, score=0.708, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.7, score=0.696, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.7, score=0.706, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.8, score=0.700, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.8, score=0.698, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.6, score=0.699, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.6, score=0.709, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.7, score=0.697, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.7, score=0.701, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.8, score=0.694, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.8, score=0.701, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.6, score=0.701, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.6, score=0.710, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.7, score=0.699, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.7, score=0.702, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.8, score=0.693, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.8, score=0.704, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.6, score=0.697, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.6, score=0.711, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.7, score=0.697, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.7, score=0.701, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.8, score=0.694, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.3, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.8, score=0.700, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.6, score=0.682, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.6, score=0.689, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.7, score=0.694, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.7, score=0.678, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.8, score=0.697, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=150, xg__subsample=0.8, score=0.694, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.6, score=0.679, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.6, score=0.688, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.7, score=0.696, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.7, score=0.682, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8, score=0.697, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8, score=0.700, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6, score=0.678, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6, score=0.694, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7, score=0.687, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7, score=0.680, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8, score=0.690, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8, score=0.688, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6, score=0.681, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6, score=0.698, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7, score=0.691, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7, score=0.679, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8, score=0.692, total=   0.1s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8, score=0.696, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6, score=0.688, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6, score=0.677, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7, score=0.677, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7, score=0.697, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8, score=0.693, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8, score=0.696, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6, score=0.684, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6, score=0.673, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7, score=0.679, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7, score=0.697, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8, score=0.692, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8, score=0.701, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6, score=0.679, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6, score=0.678, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7, score=0.684, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7, score=0.701, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8, score=0.687, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8, score=0.698, total=   0.2s
# [CV] xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.5, xg__learning_rate=0.5, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6, score=0.688, total=   0.2s
# ...
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8, score=0.680, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=160, xg__subsample=0.8, score=0.695, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6, score=0.679, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.6, score=0.676, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7, score=0.684, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.7, score=0.686, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8, score=0.678, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=170, xg__subsample=0.8, score=0.683, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6, score=0.682, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.6, score=0.679, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7, score=0.691, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.7, score=0.683, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8, score=0.683, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=4, xg__n_estimators=180, xg__subsample=0.8, score=0.695, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6, score=0.692, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.6, score=0.679, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7, score=0.691, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.7, score=0.688, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8, score=0.688, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=150, xg__subsample=0.8, score=0.703, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6, score=0.690, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.6, score=0.679, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7, score=0.698, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.7, score=0.686, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8, score=0.692, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=160, xg__subsample=0.8, score=0.694, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6, score=0.691, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.6, score=0.684, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7, score=0.693, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.7, score=0.682, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8, score=0.692, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=170, xg__subsample=0.8, score=0.700, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6, score=0.686, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.6, score=0.679, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.7, score=0.692, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.7, score=0.681, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.8, score=0.688, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=5, xg__n_estimators=180, xg__subsample=0.8, score=0.693, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.6, score=0.690, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.6, score=0.682, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.7, score=0.691, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.7, score=0.695, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.8, score=0.700, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=150, xg__subsample=0.8, score=0.702, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.6, score=0.692, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.6, score=0.680, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.7, score=0.687, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.7, score=0.706, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.8, score=0.702, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=160, xg__subsample=0.8, score=0.696, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.6, score=0.686, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.6, score=0.673, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.7, score=0.696, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.7, score=0.705, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.8, score=0.702, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=170, xg__subsample=0.8, score=0.697, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.6, score=0.683, total=   0.2s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.6
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.6, score=0.678, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.7, score=0.697, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.7
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.7, score=0.710, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.8, score=0.697, total=   0.3s
# [CV] xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.8
# [CV]  xg__colsample_bytree=0.8, xg__learning_rate=0.6, xg__max_depth=6, xg__n_estimators=180, xg__subsample=0.8, score=0.697, total=   0.3s
# [Parallel(n_jobs=1)]: Done 1152 out of 1152 | elapsed:  3.7min finished
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:823: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning
# CountVector Result:	0.7211488547217996 [Params = xg__colsample_bytree: 0.6 xg__learning_rate: 0.1 xg__max_depth: 6 xg__n_estimators: 150 xg__subsample: 0.7 ]

# %%
# clf.fit(xtrain_full_glove_np, ytrain_full)
# test_acc = metrics.f1_score(clf.predict(xtrain_full_glove_np), ytrain_full)

# print (test_acc)

# predictions = clf.predict(xtest_full_glove_np)
# output = pd.DataFrame({'id': test_df.id, 'target': predictions})
# output.to_csv('my_submission.csv', index=False)

#0.9844639286263651 / 0.79007 (using our first guess)
#0.9835359286044008 / 0.74931 (with GridSearch values)
#0.9261006289308175 / 0.79497 (new Gridsearch)
# Out:
# 0.9261006289308175

# %% [markdown]
# # 6. Deep Learning

# %%
# See separate notebook

# %% [markdown]
# ## 6.1 GPT-2 Application
#
# Source:
#  1. https://openai.com/blog/gpt-2-1-5b-release/
#  2. https://github.com/openai/gpt-2-output-dataset
